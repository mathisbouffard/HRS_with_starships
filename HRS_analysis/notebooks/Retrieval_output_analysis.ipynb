# %% [markdown]
# # STARSHIPS retrievals

# %% [markdown]
# STARSHIPS uses a combination of the MCMC package `emcee` and the radiative transfer code `petitRADTRANS` to explore a given parameter space for an atmosphere. It can combine data from multiple instruments at once, at different resolutions: high-resolution ground-based spectrographs (NIRPS, SPIRou, IGRINS, etc.), low-resolution space-based spectrographs (such as HST or JWST instruments), and photometric data points (Spitzer, etc.). A different log likelihood function is used for the high-resolution data, since defining such a function is not necessarily as straightforward as for low-resolution datasets. By default, STARSHIPS will use the equation described in _Brogi & Line (2019).
#
# STARSHIPS can perform retrievals for transmission (transit) or emission (eclipse) data, but not both simultaneously (as of now). This notebook shows an example of a transmission retrieval, but would work just the same for emission.
#
# Retrieval runs are defined by supplying a `yaml` file containing information about the run itself, the planet and its host star, and the parameters to fit for (and their priors). A timestamped version of this `yaml` file is saved for backup whenever a retrieval is launched.
#
# Typically, retrievals begin with a "burn-in" phase: a large number of walkers are initiated at random positions in the parameter space, and allowed to walk for a relatively low number of steps (e.g. a few hundred steps). A selection is then taken for the best walkers, based on log likelihood. Those best walkers are used to initialize what we call the "sampling" phase of the retrieval, where the walkers are left to explore the parameter space for a large number of steps (at least a few thousands; it can be good practice to periodically check on the walkers to assess convergence and whether it is worth letting the retrieval continue for longer).
#
# Once the walkers display a satisfying level of convergence (or lack thereof after a large number of steps), we can analyze the results. The walker file where the retrieval's output is saved will contain chains with, for each accepted step of each walker, the corresponding parameter values and the resulting log likelihood. We will use these chains to examine the posterior distributions of all the free parameters.
#
# Note that the retrieval code is set up for multiprocessing on a cluster in order to speed up calculations. Running these on a personal computer or laptop may require considerable amounts of time (and a personal download of massive opacity files required for petitRADTRANS). On a cluster, a complete retrieval can be completed on a timescale of one to two week, depending on the size of the dataset and number of parameters.

# %% [markdown]
# # Imports

# %%
from pathlib import Path

import numpy as np

import matplotlib.pyplot as plt

from starships import retrieval
from starships.plotting_fcts import get_plot_labels
import starships.retrieval_utils as ru

from starships import petitradtrans_utils

petitradtrans_utils.log.setLevel('INFO')

# %%
# %matplotlib inline

# %% [markdown]
# # Loading the retrieval

# %% [markdown]
# First we need to point to the corresponding `yaml` file for the run we want to analyze. To ensure we are using the parameters provided when the retrieval was launched, and not a potentially modified version, it may be best to point to the copy created by starships when the run was launched.

# %%
# Provide the correct path to the where the retrieval yaml files are saved
retrieval_param_outdir = Path.home() / 'scratch/temp_yamls/WASP-80b/'

# %%
# Use this to list the yaml files from the most recent
# !ls -tl $retrieval_param_outdir
# Out:
# total 604
# -rw-r-----. 1 fgenest fgenest 3112 Apr 23 19:21 params_JR_jwst_tr134_offset_no_Rp_partial_clouds_hazes_iso_H2O_CH4_no_CH4_high.yaml
# -rw-r-----. 1 fgenest fgenest 3132 Apr 14 10:44 params_JR_jwst_tr134_offset_partial_clouds_hazes_iso_H2O_CH4_no_CH4_high.yaml
# -rw-r-----. 1 fgenest fgenest 3041 Apr 12 17:35 params_LR_jwst_offset_partial_clouds_hazes_iso_H2O_CH4.yaml
# -rw-r-----. 1 fgenest fgenest 3046 Mar 31 10:34 params_JR_jwst_tr134_partial_clouds_hazes_iso_H2O_CH4_no_CH4_high.yaml
# -rw-r-----. 1 fgenest fgenest 3184 Mar 31 10:33 params_JR_jwst_tr134_partial_clouds_hazes_guillot_H2O_CH4_no_CH4_high.yaml
# -rw-r-----. 1 fgenest fgenest 2822 Mar 31 10:28 params_HR_tr134_4PCs_partial_clouds_iso_H2O.yaml
# -rw-r-----. 1 fgenest fgenest 2959 Mar 31 10:28 params_JR_jwst_tr134_4PCs_partial_clouds_iso_H2O_CH4_no_high.yaml
# -rw-r-----. 1 fgenest fgenest 2956 Mar 31 10:27 params_JR_jwst_tr134_1PC_partial_clouds_iso_H2O_CH4_no_high.yaml
# -rw-r-----. 1 fgenest fgenest 2956 Mar 31 10:27 params_JR_jwst_tr134_partial_clouds_iso_H2O_CH4_no_CH4_high.yaml
# -rw-r-----. 1 fgenest fgenest 2819 Mar 31 10:27 params_HR_tr134_1PC_partial_clouds_iso_H2O.yaml
# -rw-r-----. 1 fgenest fgenest 2812 Mar 21 17:13 params_JR_jwst_tr134_iso_fixed_Kp_fixed_H2O_CH4.yaml
# -rw-r-----. 1 fgenest fgenest 2848 Mar 20 15:53 params_JR_jwst_tr134_iso_H2O_CH4_no_CH4_high.yaml
# -rw-r-----. 1 fgenest fgenest 2955 Mar 14 22:05 params_LR_jwst_partial_clouds_hazes_iso_H2O_CH4.yaml
# -rw-r-----. 1 fgenest fgenest 3118 Mar 11 18:53 params_LR_jwst_partial_clouds_madhu_H2O_CH4.yaml
# -rw-r-----. 1 fgenest fgenest 2981 Mar 10 16:23 params_LR_jwst_partial_clouds_guillot_H2O_CH4.yaml
# -rw-r-----. 1 fgenest fgenest 2851 Mar 10 10:47 params_JR_jwst_tr134_iso_fixed_Kp_fixed_H2O_CH4_no_CH4_high.yaml
# -rw-r-----. 1 fgenest fgenest 2843 Mar  6 19:46 params_LR_jwst_partial_clouds_iso_H2O_CH4.yaml

# %%
# Choose the yaml file of the retrieval you want to analyze
yaml_file_in = retrieval_param_outdir / 'params_JR_jwst_tr134_partial_clouds_hazes_guillot_H2O_CH4_no_CH4_high.yaml'

# %% [markdown]
# Alternatively, we can directly provide a path to any `yaml` file.

# %%
# yaml_file_in = Path.home() / Path('VSCodeProjects/starships_analysis/WASP-33b/retrieval_inputs_wasp33.yaml')

# %% [markdown]
# With the `yaml` file specified, we can now load in the relevant parameters and info for the retrieval run.

# %%
retrieval.setup_retrieval(yaml_file_in)
# Out:
# INFO:starships.retrieval:photometric_data is None. Setting it to an empty dictionary instead.
# INFO:starships.retrieval:linelist_names is None. Setting it to an empty dictionary instead.
# INFO:starships.retrieval:reg_fixed_params is None. Setting it to an empty dictionary instead.
# INFO:starships.retrieval:special_init is None. Setting it to an empty dictionary instead.
# WARNING:starships.retrieval:slurm_id is in string format. It should be a number. Make sure the exponent format includes the decimal point. Ex: 1.0e-3 and not 1e-3
# INFO:starships.retrieval:instrum = ['nirps_he', 'nirps_he', 'nirps_he']
# INFO:starships.retrieval:high_res_file_stem_list = ['retrieval_input-tellu_0.3-wings_0.9-PCs_5-tr1', 'retrieval_input-tellu_0.3-wings_0.9-PCs_3-tr3', 'retrieval_input-tellu_0.7-wings_0.97-PCs_2-tr4']
# INFO:starships.retrieval:spectrophotometric_data = {'jwst': {'file_path': '/home/fgenest/projects/def-dlafre/fgenest/jwst/WASP-80b', 'file_name': 'WASP-80b_Bell2023_transspec.ecsv'}}
# INFO:starships.retrieval:photometric_data = {}
# INFO:starships.retrieval:retrieval_type = JR
# INFO:starships.retrieval:white_light = False
# INFO:starships.retrieval:chemical_equilibrium = False
# INFO:starships.retrieval:dissociation = False
# INFO:starships.retrieval:kind_temp = guillot
# INFO:starships.retrieval:run_name = JR_jwst_tr134_partial_clouds_hazes_guillot_H2O_CH4_no_CH4_high
# INFO:starships.retrieval:walker_file_out = walker_steps_JR_jwst_tr134_partial_clouds_hazes_guillot_H2O_CH4_no_CH4_high.h5
# INFO:starships.retrieval:walker_file_in = walker_steps_JR_jwst_tr134_partial_clouds_hazes_guillot_H2O_CH4_no_CH4_high.h5
# INFO:starships.retrieval:init_mode = continue
# INFO:starships.retrieval:n_cpu = 2
# INFO:starships.retrieval:n_walkers = 16
# INFO:starships.retrieval:n_walkers_per_cpu = 8
# INFO:starships.retrieval:line_opacities = ['H2O', 'CH4']
# INFO:starships.retrieval:continuum_opacities = []
# INFO:starships.retrieval:other_species = []
# INFO:starships.retrieval:species_in_prior = ['H2O', 'CH4']
# INFO:starships.retrieval:remove_mol_high = ['CH4']
# INFO:starships.retrieval:remove_mol_low = []
# INFO:starships.retrieval:pl_name = WASP-80 b
# INFO:starships.retrieval:base_dir = /scratch/fgenest
# INFO:starships.retrieval:high_res_path = /home/fgenest/scratch/reductions/WASP-80b
# INFO:starships.retrieval:star_spectrum = None
# INFO:starships.retrieval:slurm_array_behaviour = None
# INFO:starships.retrieval:n_steps_burnin = 300
# INFO:starships.retrieval:n_steps_sampling = 800
# INFO:starships.retrieval:walker_path = /home/fgenest/scratch/walker_steps/WASP-80b
# INFO:starships.retrieval:params_path = /home/fgenest/scratch/temp_yamls/WASP-80b
# INFO:starships.retrieval:params_file_out = params_JR_jwst_tr134_partial_clouds_hazes_guillot_H2O_CH4_no_CH4_high.yaml
# INFO:starships.retrieval:kind_trans = transmission
# INFO:starships.retrieval:opacity_sampling = 4
# INFO:starships.retrieval:orders = None
# INFO:starships.retrieval:pl_params = {'M_star': <Quantity 0.577 solMass>, 'R_star': <Quantity 0.586 solRad>, 'M_pl': <Quantity 0.538 jupiterMass>, 'R_pl': <Quantity 0.999 jupiterRad>, 'RV_sys': <Quantity 10.2 km / s>, 'mid_tr': <Quantity 2456487.425006 d>, 't_peri': <Quantity 2456487.425006 d>, 'trandur': <Quantity 2.131 h>, 'period': <Quantity 3.06785234 d>, 'excent': 0.0, 'incl': <Quantity 89.02 deg>, 'Teff': <Quantity 4143. K>, 'Tp': <Quantity 825. K>, 'w': <Quantity -90. deg>, 'ap': <Quantity 0.0344 AU>}
# INFO:starships.retrieval:linelist_names = {}
# INFO:starships.retrieval:limP = [-10, 2]
# INFO:starships.retrieval:n_pts = 50
# INFO:starships.retrieval:fixed_params = {'gravity': None, 'P0': 0.01, 'log_f': 0.0, 'spec_scale': 1.0, 'e-': 1e-06, 'H': 1e-99, 'C/O': None, 'Fe/H': None, 'p_cloud': None, 'scat_factor': None, 'T_eq': 825.0, 'tp_gamma': 10.0, 'T_int': 500.0, 'kappa_IR': 0.01, 'tp_delta': 1e-07, 'ptrans': 0.001, 'tp_alpha': 0.3, 'akima_P': [1e-10, 1e-05, 0.01, 10.0], 'akima_T': [1000.0, 1500.0, 2000.0, 2500.0], 'kp': 121.9, 'rv': 0.0, 'wind': None, 'phase1': 0.5, 'phase2': 0.75, 'rot_factor': 1.0}
# INFO:starships.retrieval:params_prior = {'H2O': ['log_uniform', -12.0, -0.5], 'CH4': ['log_uniform', -12.0, -0.5], 'T_eq': ['uniform', 100.0, 2000.0], 'T_int': ['uniform', 0.0, 1000.0], 'tp_gamma': ['log_uniform', -4, 6], 'kappa_IR': ['log_uniform', -4, 4], 'kp': ['uniform', 50, 200], 'rv': ['uniform', -10.0, 10.0], 'p_cloud': ['log_uniform', -8.0, 2.0], 'gamma_scat': ['uniform', -15.0, 2.0], 'scat_factor': ['log_uniform', -10.0, 10.0], 'R_pl': ['uniform', 0.9, 1.1], 'cloud_fraction': ['uniform', 0, 1]}
# INFO:starships.retrieval:region_id = [1]
# INFO:starships.retrieval:reg_params = []
# INFO:starships.retrieval:reg_fixed_params = {}
# INFO:starships.retrieval:custom_prior_file = None
# INFO:starships.retrieval:special_init = {}
# INFO:starships.retrieval:get_ker_file = None
# INFO:starships.retrieval:starships_version = 1.0.0
# INFO:starships.retrieval:slurm_id = 41958741
# INFO:starships.planet_obs:Getting WASP-80 b from ExoFile
# INFO:starships.planet_obs:Changing M_star from [1.13339363e+30] kg to 0.577 solMass
# INFO:starships.planet_obs:It became [1.1473125e+30] kg
# INFO:starships.planet_obs:Changing R_star from [3.96549e+08] m to 0.586 solRad
# INFO:starships.planet_obs:It became [4.076802e+08] m
# INFO:starships.planet_obs:Changing M_pl from [1.02119103e+27] kg to 0.538 jupiterMass
# INFO:starships.planet_obs:It became [1.02119103e+27] kg
# INFO:starships.planet_obs:Changing R_pl from [71420508.] m to 0.999 jupiterRad
# INFO:starships.planet_obs:It became [71420508.] m
# INFO:starships.planet_obs:Changing RV_sys from [0.] km / s to 10.2 km / s
# INFO:starships.planet_obs:It became [10.2] km / s
# INFO:starships.planet_obs:Changing mid_tr from [2456671.49615] d to 2456487.425006 d
# INFO:starships.planet_obs:It became [2456487.425006] d
# INFO:starships.planet_obs:Changing t_peri from [2456671.49615] d to 2456487.425006 d
# INFO:starships.planet_obs:It became [2456487.425006] d
# INFO:starships.planet_obs:Changing trandur from [7671.6] s to 2.131 h
# INFO:starships.planet_obs:It became [7671.6] s
# INFO:starships.planet_obs:Changing period from [265062.474144] s to 3.06785234 d
# INFO:starships.planet_obs:It became [265062.442176] s
# INFO:starships.planet_obs:Changing excent from pl_orbeccen
# -----------
#       0.002 to 0.0
# INFO:starships.planet_obs:It became 0.0
# INFO:starships.planet_obs:Changing incl from [1.5536921] rad to 89.02 deg
# INFO:starships.planet_obs:It became [1.5536921] rad
# INFO:starships.planet_obs:Changing Teff from [4145.] K to 4143.0 K
# INFO:starships.planet_obs:It became [4143.] K
# INFO:starships.planet_obs:Changing Tp from [825.] K to 825.0 K
# INFO:starships.planet_obs:It became [825.] K
# INFO:starships.planet_obs:Changing w from [6.35299848] rad to -90.0 deg
# INFO:starships.planet_obs:It became [-1.57079633] rad
# INFO:starships.planet_obs:Changing ap from [5.14616675e+09] m to 0.0344 AU
# INFO:starships.planet_obs:It became [5.14616675e+09] m
# INFO:starships.retrieval:wavelength range for model at high res: [[0.9, 1.98]]
# INFO:starships.retrieval:Loading data for instrument jwst
# INFO:starships.retrieval:wavelength range for model at low res: [[0.9, 4.156887500000001]]
# INFO:starships.retrieval_utils:Generating initial walkers from prior.
# {'instrum': ['nirps_he', 'nirps_he', 'nirps_he'],
#  'high_res_file_stem_list': ['retrieval_input-tellu_0.3-wings_0.9-PCs_5-tr1',
#   'retrieval_input-tellu_0.3-wings_0.9-PCs_3-tr3',
#   'retrieval_input-tellu_0.7-wings_0.97-PCs_2-tr4'],
#  'spectrophotometric_data': {'jwst': {'file_path': '/home/fgenest/projects/def-dlafre/fgenest/jwst/WASP-80b',
#    'file_name': 'WASP-80b_Bell2023_transspec.ecsv',
#    'wave': array([2.4218 , 2.43615, 2.45045, 2.4648 , 2.47915, 2.4935 , 2.5079 ,
#           2.5223 , 2.53665, 2.551  , 2.5654 , 2.5798 , 2.5942 , 2.6086 ,
#           2.62305, 2.6375 , 2.6519 , 2.6663 , 2.68075, 2.6952 , 2.70965,
#           2.7241 , 2.73855, 2.75305, 2.76755, 2.782  , 2.79645, 2.81095,
#           2.82545, 2.83995, 2.85445, 2.86895, 2.88345, 2.898  , 2.91255,
#           2.92705, 2.9416 , 2.95615, 2.97065, 2.9852 , 2.99975, 3.0143 ,
#           3.0289 , 3.04345, 3.058  , 3.0726 , 3.0872 , 3.10175, 3.1163 ,
#           3.1309 , 3.1455 , 3.1601 , 3.1747 , 3.1893 , 3.2039 , 3.2185 ,
#           3.23315, 3.2478 , 3.2624 , 3.277  , 3.29165, 3.3063 , 3.3209 ,
#           3.33555, 3.3502 , 3.36485, 3.3795 , 3.39415, 3.4088 , 3.42345,
#           3.4381 , 3.45275, 3.46745, 3.4821 , 3.49675, 3.51145, 3.52615,
#           3.5408 , 3.55545, 3.57015, 3.58485, 3.59955, 3.61425, 3.6289 ,
#           3.64355, 3.65825, 3.67295, 3.68765, 3.70235, 3.71705, 3.73175,
#           3.74645, 3.76115, 3.77585, 3.79055, 3.8053 , 3.82005, 3.83475,
#           3.84945, 3.86415, 3.87885, 3.89355, 3.9083 , 3.92305, 3.93775,
#           3.95245, 3.96715, 3.98185, 3.9966 , 4.01135, 4.02605, 4.04075,
#           4.0555 ]),
#    'data': array([0.02958064, 0.0295253 , 0.02951508, 0.02959694, 0.02941273,
#           0.02965144, 0.02962941, 0.02964242, 0.02953395, 0.02943973,
#           0.0296339 , 0.02967923, 0.02979789, 0.02974488, 0.02966489,
#           0.02975916, 0.02972567, 0.02971438, 0.0298034 , 0.02968056,
#           0.02978674, 0.02978316, 0.02962308, 0.0297713 , 0.02963748,
#           0.02978034, 0.02987364, 0.02979799, 0.02968562, 0.02972098,
#           0.02961831, 0.0294088 , 0.0297105 , 0.02962541, 0.02966713,
#           0.02976654, 0.02968706, 0.02967307, 0.02955021, 0.02965257,
#           0.02966923, 0.02992541, 0.02971147, 0.02962814, 0.02972859,
#           0.02967585, 0.02970619, 0.0297182 , 0.0297623 , 0.02971832,
#           0.0296551 , 0.02974097, 0.02982252, 0.02974285, 0.02966553,
#           0.02982092, 0.02954487, 0.02959773, 0.02966486, 0.02953935,
#           0.02972618, 0.02959326, 0.02986588, 0.02976175, 0.0298027 ,
#           0.02979107, 0.02960983, 0.02958112, 0.02957597, 0.02959459,
#           0.02957647, 0.02973986, 0.02975514, 0.02965321, 0.02963057,
#           0.02972152, 0.02955987, 0.02959937, 0.02962655, 0.02973662,
#           0.02962608, 0.02964727, 0.02959031, 0.0296101 , 0.0295967 ,
#           0.02951976, 0.02953332, 0.02959721, 0.02947791, 0.029422  ,
#           0.02960303, 0.02931678, 0.02943874, 0.02956963, 0.0295366 ,
#           0.02941837, 0.02940046, 0.02944203, 0.02948615, 0.02961672,
#           0.02959595, 0.02932743, 0.02928401, 0.02927989, 0.02937063,
#           0.029366  , 0.02938985, 0.02936107, 0.0293311 , 0.02934496,
#           0.02934563, 0.0293983 , 0.02918401]),
#    'err': array([1.59864871e-04, 1.32531273e-04, 1.33726842e-04, 1.27729922e-04,
#           1.21730941e-04, 1.21169479e-04, 1.31746403e-04, 1.20961380e-04,
#           1.16108604e-04, 1.48937154e-04, 1.13537876e-04, 1.14937388e-04,
#           1.20592556e-04, 1.07922487e-04, 1.04780879e-04, 1.05780409e-04,
#           1.02569291e-04, 1.03013710e-04, 9.58848774e-05, 1.03799102e-04,
#           1.40088495e-04, 9.38727372e-05, 1.02028966e-04, 1.12314638e-04,
#           9.72888937e-05, 9.84861288e-05, 1.01136569e-04, 1.06441920e-04,
#           9.50904680e-05, 9.58270585e-05, 1.36319511e-04, 1.03331935e-04,
#           1.13678446e-04, 1.20810525e-04, 1.05292773e-04, 1.00094242e-04,
#           1.23728571e-04, 9.77066128e-05, 1.10427022e-04, 1.05874205e-04,
#           1.24796664e-04, 1.49633191e-04, 1.00666187e-04, 1.24608541e-04,
#           1.02159742e-04, 9.24506116e-05, 8.96763356e-05, 1.04332020e-04,
#           1.41304965e-04, 1.41391628e-04, 9.27682787e-05, 8.68149935e-05,
#           1.03987627e-04, 9.34913787e-05, 9.64264305e-05, 9.09098486e-05,
#           1.10733024e-04, 9.26093168e-05, 8.73003846e-05, 1.02695222e-04,
#           8.94585820e-05, 9.05453777e-05, 9.01639969e-05, 9.94587643e-05,
#           9.01230712e-05, 1.17606606e-04, 9.52325212e-05, 8.86456194e-05,
#           9.75332496e-05, 8.92474019e-05, 9.71065107e-05, 1.06602099e-04,
#           1.54372390e-04, 1.02189649e-04, 9.91051405e-05, 9.40540090e-05,
#           9.35443241e-05, 1.06861705e-04, 1.02329750e-04, 1.00709361e-04,
#           9.16214522e-05, 9.48227945e-05, 9.19309883e-05, 9.96293004e-05,
#           1.02807102e-04, 1.08668716e-04, 1.07974462e-04, 1.37377123e-04,
#           1.01049997e-04, 1.00839448e-04, 1.03607226e-04, 9.47681034e-05,
#           9.61981226e-05, 9.78025124e-05, 1.08394452e-04, 1.06780503e-04,
#           1.13677418e-04, 1.03526071e-04, 2.67509895e-04, 1.08921947e-04,
#           1.42323899e-04, 9.85511529e-05, 9.38952248e-05, 1.21046960e-04,
#           1.14447042e-04, 9.98276439e-05, 1.13257646e-04, 1.33752406e-04,
#           2.04069045e-04, 2.05104307e-04, 2.70056769e-04, 4.44016412e-04,
#           5.74974688e-04]),
#    'res': 200,
#    'wv_range': [2.3612550000000003, 4.156887500000001],
#    'model_type': 'low'}},
#  'photometric_data': {},
#  'retrieval_type': 'JR',
#  'white_light': False,
#  'chemical_equilibrium': False,
#  'dissociation': False,
#  'kind_temp': 'guillot',
#  'run_name': 'JR_jwst_tr134_partial_clouds_hazes_guillot_H2O_CH4_no_CH4_high',
#  'walker_file_out': PosixPath('walker_steps_JR_jwst_tr134_partial_clouds_hazes_guillot_H2O_CH4_no_CH4_high.h5'),
#  'walker_file_in': PosixPath('walker_steps_JR_jwst_tr134_partial_clouds_hazes_guillot_H2O_CH4_no_CH4_high.h5'),
#  'init_mode': 'continue',
#  'n_cpu': 2,
#  'n_walkers': 16,
#  'n_walkers_per_cpu': 8,
#  'line_opacities': ['H2O', 'CH4'],
#  'continuum_opacities': [],
#  'other_species': [],
#  'species_in_prior': ['H2O', 'CH4'],
#  'remove_mol_high': ['CH4'],
#  'remove_mol_low': [],
#  'pl_name': 'WASP-80 b',
#  'base_dir': PosixPath('/scratch/fgenest'),
#  'high_res_path': PosixPath('/home/fgenest/scratch/reductions/WASP-80b'),
#  'star_spectrum': None,
#  'slurm_array_behaviour': None,
#  'n_steps_burnin': 300,
#  'n_steps_sampling': 800,
#  'walker_path': PosixPath('/home/fgenest/scratch/walker_steps/WASP-80b'),
#  'params_path': PosixPath('/home/fgenest/scratch/temp_yamls/WASP-80b'),
#  'params_file_out': PosixPath('params_JR_jwst_tr134_partial_clouds_hazes_guillot_H2O_CH4_no_CH4_high.yaml'),
#  'kind_trans': 'transmission',
#  'opacity_sampling': 4,
#  'orders': None,
#  'pl_params': {'M_star': <Quantity 0.577 solMass>,
#   'R_star': <Quantity 0.586 solRad>,
#   'M_pl': <Quantity 0.538 jupiterMass>,
#   'R_pl': <Quantity 0.999 jupiterRad>,
#   'RV_sys': <Quantity 10.2 km / s>,
#   'mid_tr': <Quantity 2456487.425006 d>,
#   't_peri': <Quantity 2456487.425006 d>,
#   'trandur': <Quantity 2.131 h>,
#   'period': <Quantity 3.06785234 d>,
#   'excent': 0.0,
#   'incl': <Quantity 89.02 deg>,
#   'Teff': <Quantity 4143. K>,
#   'Tp': <Quantity 825. K>,
#   'w': <Quantity -90. deg>,
#   'ap': <Quantity 0.0344 AU>},
#  'linelist_names': {},
#  'limP': [-10, 2],
#  'n_pts': 50,
#  'fixed_params': {'gravity': array([1336.1857832]),
#   'P0': 0.01,
#   'log_f': 0.0,
#   'spec_scale': 1.0,
#   'e-': 1e-06,
#   'H': 1e-99,
#   'C/O': None,
#   'Fe/H': None,
#   'p_cloud': None,
#   'scat_factor': None,
#   'T_eq': 825.0,
#   'tp_gamma': 10.0,
#   'T_int': 500.0,
#   'kappa_IR': 0.01,
#   'tp_delta': 1e-07,
#   'ptrans': 0.001,
#   'tp_alpha': 0.3,
#   'akima_P': [1e-10, 1e-05, 0.01, 10.0],
#   'akima_T': [1000.0, 1500.0, 2000.0, 2500.0],
#   'kp': 121.9,
#   'rv': 0.0,
#   'wind': None,
#   'phase1': 0.5,
#   'phase2': 0.75,
#   'rot_factor': 1.0,
#   'pressures': array([1.00000000e-10, 1.75751062e-10, 3.08884360e-10, 5.42867544e-10,
#          9.54095476e-10, 1.67683294e-09, 2.94705170e-09, 5.17947468e-09,
#          9.10298178e-09, 1.59985872e-08, 2.81176870e-08, 4.94171336e-08,
#          8.68511374e-08, 1.52641797e-07, 2.68269580e-07, 4.71486636e-07,
#          8.28642773e-07, 1.45634848e-06, 2.55954792e-06, 4.49843267e-06,
#          7.90604321e-06, 1.38949549e-05, 2.44205309e-05, 4.29193426e-05,
#          7.54312006e-05, 1.32571137e-04, 2.32995181e-04, 4.09491506e-04,
#          7.19685673e-04, 1.26485522e-03, 2.22299648e-03, 3.90693994e-03,
#          6.86648845e-03, 1.20679264e-02, 2.12095089e-02, 3.72759372e-02,
#          6.55128557e-02, 1.15139540e-01, 2.02358965e-01, 3.55648031e-01,
#          6.25055193e-01, 1.09854114e+00, 1.93069773e+00, 3.39322177e+00,
#          5.96362332e+00, 1.04811313e+01, 1.84206997e+01, 3.23745754e+01,
#          5.68986603e+01, 1.00000000e+02]),
#   'temperatures': None,
#   'M_pl': array([0.538]),
#   'R_pl': array([0.999]),
#   'R_star': array([0.586])},
#  'params_prior': {'H2O': ['log_uniform', -12.0, -0.5],
#   'CH4': ['log_uniform', -12.0, -0.5],
#   'T_eq': ['uniform', 100.0, 2000.0],
#   'T_int': ['uniform', 0.0, 1000.0],
#   'tp_gamma': ['log_uniform', -4, 6],
#   'kappa_IR': ['log_uniform', -4, 4],
#   'kp': ['uniform', 50, 200],
#   'rv': ['uniform', -10.0, 10.0],
#   'p_cloud': ['log_uniform', -8.0, 2.0],
#   'gamma_scat': ['uniform', -15.0, 2.0],
#   'scat_factor': ['log_uniform', -10.0, 10.0],
#   'R_pl': ['uniform', 0.9, 1.1],
#   'cloud_fraction': ['uniform', 0, 1]},
#  'region_id': [1],
#  'reg_params': [],
#  'reg_fixed_params': {},
#  'custom_prior_file': None,
#  'special_init': {},
#  'get_ker_file': None,
#  'starships_version': '1.0.0',
#  'slurm_id': '41958741'}

# %% [markdown]
# We then get the plot labels for the retrieved parameters, the default walker file path as defined in the `yaml` file, and check the default walker file name. If the default walker file name does not point to the correct file (or to any valid file at all), we can provide the correct file manually.

# %%
# Get labels
labels = get_plot_labels(params=retrieval.params_prior)

# Get walker output path
walker_path = retrieval.walker_path

print('Default retrieval walker file:', retrieval.walker_file_out)
# Out:
# Default retrieval walker file: walker_steps_JR_jwst_tr134_partial_clouds_hazes_guillot_H2O_CH4_no_CH4_high.h5

# %% [markdown]
# The retrieval `walker_file` can be changed as long as it has the same parameters as in the `yaml` file provided earlier.

# %%
# Show latest 50 (or change to any number you would like) walker files in the walker_path directory
# !ls -t1 $walker_path | head -50

# %% [markdown]
# ## Read the walker file

# %% [markdown]
# We can first read the walker file and store information about the parameter values at each step in the `chains` array. When using `read_walkers_file`, the steps will be ordered in the same way they happened during the retrieval. It is possible to discard a specified number of initial steps by using the `discard` argument.
#
# STARSHIPS will notify whether all planned walker steps were completed or not; incomplete walker steps means either the retrieval was manually cancelled before it reached its set number of steps from the `yaml`, or ran out of time (if run on a cluster with a job scheduling system, for example).

# %%
# We can provide a walker file different from the default one from the yaml if we want
# walker_file = Path('walker_steps_emission_LRR_wfc3_spitzer_modif_disso_32470473_burnin.h5')

# But generally we simply want to use the yaml's default walker file
walker_file = retrieval.walker_file_out

print('walker file:', walker_file)
chains = ru.read_walkers_file(walker_path / walker_file, discard=0)
# Out:
# walker file: walker_steps_JR_jwst_tr134_partial_clouds_hazes_guillot_H2O_CH4_no_CH4_high.h5
# INFO:starships.retrieval_utils:Steps in walkers file are all completed

# %% [markdown]
# The chains array has the shape (n_steps, n_walkers, n_parameters)

# %%
chains.shape
# Out:
# (6400, 160, 13)

# %%
# Review the parameter plotting labels, can edit these if you like (for clairty or any other reason)
labels
# Out:
# ['$\\log_{10}$ H$_2$O',
#  'CH4',
#  'T_eq',
#  'T_int',
#  '$\\log_{10} \\gamma$',
#  'kappa_IR',
#  '$K_{\\rm P}$',
#  '$v_{\\rm rad}$',
#  'p_cloud',
#  'gamma_scat',
#  'scat_factor',
#  'R_pl',
#  'cloud_fraction']

# %% [markdown]
# # First plots

# %% [markdown]
# ## Walker steps

# %% [markdown]
# The first thing we might want to look at is the progress of walkers for each parameter. The central panel will show the evolution of parameter values for all chains as a function of step number. The rightmost panel will show the distribution of those parameter values.
#
# This plot is a good diagnostic of convergence for the various parameters: most walkers should converge to similar values, and this behaviour should be visible in the initial steps (not as much if a relatively long burn-in was used). On the other hand, for parameters with little convergence or constraints, the chain plots will look very noisy or messy, with no clear behavior, and the distribution plots will be very wide or even flat.

# %%
maxs, errors = ru.find_dist_maxs(chains, labels, bin_size=6, print_latex_style=False, alpha_plot=0.1)
# Out:
# $\log_{10}$ H$_2$O: Maximum=-2.0486204806928385, Error=[-0.54859738  0.52282834], HDI(68.00%)=[-2.59721786 -1.52579214]
# CH4: Maximum=-4.51867396077115, Error=[-0.7942452  0.7572113], HDI(68.00%)=[-5.31291916 -3.76146266]
# T_eq: Maximum=348.4615925167878, Error=[-119.53680578   93.07321485], HDI(68.00%)=[228.92478673 441.53480736]
# T_int: Maximum=343.85616267439923, Error=[-232.58469889   88.69364106], HDI(68.00%)=[111.27146379 432.54980374]
# $\log_{10} \gamma$: Maximum=-0.4578690396687263, Error=[-3.37756457  1.06515793], HDI(68.00%)=[-3.83543361  0.60728889]
# kappa_IR: Maximum=-2.672742199680515, Error=[-1.31863402  1.03671835], HDI(68.00%)=[-3.99137622 -1.63602385]
# $K_{\rm P}$: Maximum=121.73720058827556, Error=[-17.15273615  22.14145125], HDI(68.00%)=[104.58446444 143.87865184]
# $v_{\rm rad}$: Maximum=-3.9022313506531643, Error=[-0.76524276  0.8997749 ], HDI(68.00%)=[-4.66747411 -3.00245645]
# p_cloud: Maximum=0.592014986633791, Error=[-1.97794114  1.40737027], HDI(68.00%)=[-1.38592615  1.99938525]
# gamma_scat: Maximum=-12.772839910425441, Error=[-2.2201658   7.96998627], HDI(68.00%)=[-14.99300571  -4.80285364]
# scat_factor: Maximum=-4.11216569803991, Error=[-5.8807526   4.81059934], HDI(68.00%)=[-9.9929183   0.69843364]
# R_pl: Maximum=0.9806421984530531, Error=[-0.00109623  0.00108134], HDI(68.00%)=[0.97954597 0.98172354]
# cloud_fraction: Maximum=0.09743604268346319, Error=[-0.09743471  0.38007682], HDI(68.00%)=[1.33236340e-06 4.77512859e-01]

# %% [markdown]
# Computing mean and spread/uncertainty statistics on the distrubutions.

# %%
maxs2s, errors2s = ru.find_dist_maxs(chains, labels, bin_size=6, prob=0.954, plot=False, print_latex_style=False)
# Out:
# $\log_{10}$ H$_2$O: Maximum=-2.0486204806928385, Error=[-1.08209825  0.90310531], HDI(95.40%)=[-3.13071873 -1.14551517]
# CH4: Maximum=-4.51867396077115, Error=[-3.11644795  1.89004929], HDI(95.40%)=[-7.63512191 -2.62862467]
# T_eq: Maximum=348.4615925167878, Error=[-248.46144771   99.17918845], HDI(95.40%)=[100.00014481 447.64078097]
# T_int: Maximum=343.85616267439923, Error=[-343.84139658   93.84721678], HDI(95.40%)=[1.47660947e-02 4.37703379e+02]
# $\log_{10} \gamma$: Maximum=-0.4578690396687263, Error=[-3.5371793   5.96086477], HDI(95.40%)=[-3.99504834  5.50299573]
# kappa_IR: Maximum=-2.672742199680515, Error=[-1.32725468  4.26512459], HDI(95.40%)=[-3.99999688  1.59238239]
# $K_{\rm P}$: Maximum=121.73720058827556, Error=[-29.461664    55.99695762], HDI(95.40%)=[ 92.27553659 177.73415821]
# $v_{\rm rad}$: Maximum=-3.9022313506531643, Error=[-1.24065446  2.6228439 ], HDI(95.40%)=[-5.14288581 -1.27938745]
# p_cloud: Maximum=0.592014986633791, Error=[-7.64520206  1.40798376], HDI(95.40%)=[-7.05318708  1.99999874]
# gamma_scat: Maximum=-12.772839910425441, Error=[-2.22449269 13.61756113], HDI(95.40%)=[-14.9973326    0.84472122]
# scat_factor: Maximum=-4.11216569803991, Error=[-5.88645348 11.69556403], HDI(95.40%)=[-9.99861918  7.58339833]
# R_pl: Maximum=0.9806421984530531, Error=[-0.00273649  0.00217421], HDI(95.40%)=[0.97790571 0.9828164 ]
# cloud_fraction: Maximum=0.09743604268346319, Error=[-0.09743471  0.81246227], HDI(95.40%)=[1.33236340e-06 9.09898314e-01]

# %% [markdown]
# ## Corner plot

# %% [markdown]
# The corner plot is one of the most popular ways to display and analyze a retrieval's output. Density plots of the distributions of walkers are plotted for every pair of parameters, showing the covariance of parameters. This is a great tool to identify or confirm any correlation or degeneracy between parameters.
#
# At the top of each columns, the marginalized posterior distribution for each parameter is plotted, along with their mean and spread. Note that those statistics are definitely more reliable and meaningful for Gaussian distributions.
#
# Optionally, it is possible to restrain the corner plot to only a subset of parameters by first taking an appropriate subset of `chains` and `labels` and then going through with making the plots.

# %%
fig, flat_samples = ru.plot_corner(chains, labels, param_no_zero=4, maxs=maxs, errors=errors, plot_datapoints=False)

# %%
# Optionally, save the figure
# The default filename here uses the retrieval run name and the number of walker steps
# However, feel free to use any file name you like

# path_fig = Path.home() / 'nirps/retrievals/plots/WASP-80b'
# n_steps = str(chains.shape[0])
# fig.savefig(path_fig / f'{walker_file.name[:-3]}_{n_steps}_steps_corner_plot.pdf')

# %% [markdown]
# # Further analysis

# %% [markdown]
# Before continuing with a few extra analysis steps, we will load information from the walker file again, but this time we will also get the log likelihood at each step. Aditionnally, we will order the sample by log L (best/highest log L will be last). Again, a number of initial steps may be discarded using the `discard` argument.

# %%
# Get the posterior distribution ordered by their logl value (last value is the highest logl)
output = ru.read_walker_prob(walker_path/walker_file, tol=8, discard=1500)

ord_pos, ord_logl, autocorr = output

# %% [markdown]
# ## Verify the logl for each parameters
# ** This is especially useful if you want to do some analysis on burnin results

# %% [markdown]
# The log L distributions for each parameter can also be used to assess whether the retrieval is converging properly, i.e. finding a true maximum in log L.
#
# Based on the log L scatter plot (see below):
# - For burnins, are there 2 clear blobs separated vertically (in logl value)?
# - Is there an actual maximum?
# - Are some walker stuck in a secondary maximum (if so, we might remove them)
# - Do you want to restrain the parameters to a subsample for later use? Like to generate the spectra.

# %%
from starships.plotting_fcts import scatterplot_logl

# %%
print('Median logl value:', np.median(ord_logl))
# Out:
# Median logl value: 1894826.2179669214

# %%
prior_keys = list(retrieval.params_prior.keys())

# %%
# Make a selection of the walker if wanted

# On the logl (Set it to -np.inf if not used)
cond = ord_logl > -np.inf

# and/or any other conditions

ord_pos_sub = ord_pos[cond]
ord_logl_sub = ord_logl[cond]

# %%
fig, ax = scatterplot_logl(ord_pos, ord_logl, n_max_pts=10000, tight_ylim=True,
                           alpha=0.1, color='k', ylabels=labels)

# Comment/uncomment the following lines to plot the sub_samples
# _ = scatterplot_logl(ord_pos_sub, ord_logl_sub, n_max_pts=10000, tight_ylim=True,
#                            alpha=0.3, color='darkgreen', ylabels=labels, ax=ax)

# %% [markdown]
# You can also remake the corner plot and walker steps plot (this time, ordered by increasing log likelihood) for the subsample if you want.

# %%
fig, flat_samples = ru.plot_corner(ord_pos_sub[:, None, :], labels, param_no_zero=4, plot_datapoints=False)
# Out:
# $\log_{10}$ H$_2$O: Maximum=-2.0336378684164904, Error=[-0.54528304  0.50685913], HDI(68.00%)=[-2.5789209  -1.52677874]
# CH4: Maximum=-4.491971894363869, Error=[-0.77057289  0.74783599], HDI(68.00%)=[-5.26254478 -3.74413591]
# T_eq: Maximum=351.2317513598619, Error=[-120.37193888   91.31563788], HDI(68.00%)=[230.85981248 442.54738924]
# T_int: Maximum=349.7821712016375, Error=[-349.76740511  -27.03159786], HDI(68.00%)=[1.47660947e-02 3.22750573e+02]
# $\log_{10} \gamma$: Maximum=-0.4197763751248214, Error=[-3.41570467  0.97885138], HDI(68.00%)=[-3.83548104  0.559075  ]
# kappa_IR: Maximum=-2.837182518243077, Error=[-1.15406     1.15336863], HDI(68.00%)=[-3.99124252 -1.68381389]
# $K_{\rm P}$: Maximum=121.17818127979845, Error=[-16.19310866  22.59712021], HDI(68.00%)=[104.98507262 143.77530149]
# $v_{\rm rad}$: Maximum=-3.9189909642365857, Error=[-0.73885475  0.89665416], HDI(68.00%)=[-4.65784571 -3.02233681]
# p_cloud: Maximum=0.6644798297616548, Error=[-1.8684209   1.33551891], HDI(68.00%)=[-1.20394107  1.99999874]
# gamma_scat: Maximum=-12.840524261912675, Error=[-2.15439345  7.95733656], HDI(68.00%)=[-14.99491771  -4.8831877 ]
# scat_factor: Maximum=-7.182624123765404, Error=[-2.81018953  7.79498821], HDI(68.00%)=[-9.99281365  0.61236408]
# R_pl: Maximum=0.9806175890631926, Error=[-0.00101467  0.00110905], HDI(68.00%)=[0.97960292 0.98172664]
# cloud_fraction: Maximum=0.09548660928823131, Error=[-0.09548565  0.39573789], HDI(68.00%)=[9.64209323e-07 4.91224503e-01]

# %% [markdown]
# # Explore confidence intervals

# %% [markdown]
# Here we present a few toos to look at posterior statistics for the temperature-pressure and abundance profiles.

# %% [markdown]
# ## Abundances and TP profiles

# %% [markdown]
# First we load in useful functions from starships to draw samples for these profiles, and plot them.

# %%
from starships.retrieval_utils import draw_profiles_form_sample, get_stats_from_profile

# %%
from starships.plotting_fcts import plot_p_profile_sample, plot_tp_sample

# %% [markdown]
# ### Chose which sample to use
# This can be a subsample defined by chosen conditions earlier.

# %%
# flatten_sample = flat_samples
# flatten_sample = chains.reshape((-1, chains.shape[-1]))
flatten_sample = ord_pos_sub

# %%
from starships.petitradtrans_utils import gen_abundances

# %%
# Definitions for a few utility functions for getting profile samples from our walkers
def get_tp_profile(params, idx_region=0):
    
    theta_dict = retrieval.unpack_theta(params)[idx_region]
    return theta_dict['pressures'], theta_dict['temperatures']


def get_mol_profile(params, idx_region=0):
    
    theta_dict = retrieval.unpack_theta(params)[idx_region]
    
    species = retrieval.line_opacities + retrieval.continuum_opacities + retrieval.other_species
    # Compute the abundances (and add species that need to be included if not fitted)
    abundances, MMW, VMR = gen_abundances(species, [theta_dict[key] for key in species],
                                     theta_dict['pressures'], theta_dict['temperatures'],
                                     verbose=False, vmrh2he=[0.85, 0.15],
                                     dissociation=retrieval.dissociation, plot=False)
    
    return VMR

# %%
# Combined list of all chemical species included in the retrieval
all_species = retrieval.line_opacities + retrieval.continuum_opacities + retrieval.other_species

# %%
# And now we actually draw the random sample profiles (here, 500; feel free to adjust this number)
profile_samples, pressures = draw_profiles_form_sample(500, flatten_sample, 
                                                       list_mols=all_species,
                                                       get_mol_profile=get_mol_profile, 
                                                       get_tp_from_param=get_tp_profile)

# Add a check to make sure the values are reasonnable
profile_stats = {key: get_stats_from_profile(val, log_scale=True)
                 for key, val in profile_samples.items()
                 if key != 'temperature'}
for key, val in profile_samples.items():
    if key != 'temperature':
        profile_samples[key] = np.clip(profile_samples[key], 1e-20, 1.)
    else:
        profile_samples[key] = np.clip(profile_samples[key], 0., 10000.)

# %% [markdown]
# `profile_samples` contains samples for all the species that the model uses, and also the pressure-temperature profile.

# %% [markdown]
# ### Example profiles drawn from the sample

# %% [markdown]
# The shape of the profiles will depend on what was specified in the retrievals. For example, if the temperature profile was set to `isothermal`, then all profiles will be constant with pressure/altitude; if `Guillot` or another non-isothermal profile was used, we will get profiles that vary with pressure.
#
# Abundance profiles will be constant with pressure by default in free chemistry retrievals.

# %%
mol_name = 'H2O'

fig, ax = plt.subplots(1, 2, sharey=True)
ax[0].semilogy(profile_samples['temperature'].T, pressures, "k", alpha=0.1)
ax[0].invert_yaxis()

ax[1].loglog(profile_samples[mol_name].T, pressures, "k", alpha=0.2)
ax[1].set_title(mol_name)

ax[0].set_ylabel('Pressure')
ax[0].set_xlabel('Temperature')
ax[1].set_xlabel('Abundance')
# Out:
# Text(0.5, 0, 'Abundance')

# %% [markdown]
# ### Statistics from these samples (median, 1-sigma, 2-sigma)

# %%
# Get statistics. Done in logspace for molecules, but not for temperature
profile_stats = {key: get_stats_from_profile(val, log_scale=True)
                 for key, val in profile_samples.items()
                 if key != 'temperature'}
profile_stats['temperature'] = get_stats_from_profile(profile_samples['temperature'])

# %% [markdown]
# ### TP profiles statistics

# %%
fig1, ax = plot_tp_sample(pressures, profile_stats['temperature'], p_range=(1e-10, 1e2))

# %% [markdown]
# ### Abundance profiles statistics

# %% [markdown]
# This is especially useful visualization for retrievals where certain species are expected to vary significantly with altitude/pressure (e.g. H2O/OH in hot atmospheres).

# %%
# Feel free to include more species form the retrieval
# and to add more sublots and separate species into groups for a good visualization
# For example, plot together two species for which the abundances are correlated

fig, ax = plt.subplots(1, 2, sharey=True, figsize=(6, 4))

plot_tp_sample(pressures, profile_stats['temperature'], ax=ax[0])

for mol_name in ['H2O', 'CH4']:
    plot_p_profile_sample(pressures, profile_stats[mol_name], ax=ax[1], label=mol_name)
ax[1].set_xscale('log')
ax[1].set_xlim(1e-12, 1e0)
ax[1].legend()

ax[1].set_xlabel('Volume Mixing Ratio', fontsize='large')
# Out:
# Text(0.5, 0, 'Volume Mixing Ratio')

# %% [markdown]
# # --- petitRADTRANS required past this point ---

# %% [markdown]
# All the remaining sections of the notebook require petitRADTRANS to compute models, so they were moved here to the end for reference purposes. They are also less commented.

# %% [markdown]
# ### You can also overplot what is expected from chemical equilibrium

# %% [markdown]
# The plots in this subsection are from a completely different retrieval.

# %%
from petitRADTRANS.poor_mans_nonequ_chem import interpol_abundances
from starships.petitradtrans_utils import mass_frac_2_vmr

# %%
c_to_o = .95
Fe_to_H = None

# Compute Fe/H if Fe is available
if Fe_to_H is None and 'Fe' in profile_samples:
    pro_val = list(profile_samples.values())
    list_species=profile_samples.keys()
    Fe_profiles = ru.get_atom_abundance('Fe', pro_val, list_species=list_species)
    H_profiles = ru.get_atom_abundance('H', pro_val, list_species=list_species)
    # log10 VMR_Fe / VMR_H = -4.46 (=12. - 7.54)  (solar protosolar metallicity form Asplund 2009 table 5)
    FeHs = np.log10(Fe_profiles / H_profiles) - (-4.46)
else:
    if Fe_to_H is None:
        Fe_to_H = 0.
    FeHs = np.full_like(pressures, Fe_to_H)
    FeHs = np.broadcast_to(FeHs, profile_samples['temperature'].shape)

COs = c_to_o * np.ones_like(pressures)
profile_samples_eq = dict()
for i_sample, temp in enumerate(profile_samples['temperature']):
    
        
    mass_fractions = interpol_abundances(COs, FeHs[i_sample], temp, pressures)
    vmrs = mass_frac_2_vmr(mass_frac_dict=mass_fractions)
    for specie in vmrs:
        try: 
            profile_samples_eq[specie]
        except KeyError:
            profile_samples_eq[specie] = []
        profile_samples_eq[specie].append(vmrs[specie])
# Convert to array
for key, val in profile_samples_eq.items():
    profile_samples_eq[key] = np.array(val)
    
# Get statistics. Done  in logspace for molecules
profile_stats_eq = {key: get_stats_from_profile(val, log_scale=True)
                 for key, val in profile_samples_eq.items()}

# %%
# Choose which specie to plot
species_plt = [specie for specie in profile_stats_eq if profile_stats_eq[specie]['median'].max() > 1e-6]

# %%
# %matplotlib inline

# %%
fig, ax = plt.subplots(3, 1, sharey=True, figsize=(8, 16))

for specie in profile_stats:
    if specie in profile_stats_eq:
        plot_p_profile_sample(pressures, profile_stats[specie], ax=ax[0], label=specie)
        plot_p_profile_sample(pressures, profile_stats_eq[specie], ax=ax[1], label=specie)
        
for specie in species_plt:
    if specie not in profile_stats:
        plot_p_profile_sample(pressures, profile_stats_eq[specie], ax=ax[2], label=specie)
        
        
ax[0].set_title('Free Chemistry (shared species)', loc='left', fontsize='small')
ax[1].set_title('Equilibrium Chemistry (shared species)', loc='left', fontsize='small')
ax[2].set_title('Equilibrium Chemistry (not in Free Chemistry)', loc='left', fontsize='small')

for ax_i in ax:
    ax_i.set_xscale('log')
    ax_i.set_xlim(1e-12, 1e0)
    ax_i.legend(fontsize='small')
    ax_i.set_ylabel('Pressure [bar]', fontsize='large')
    
ax[2].set_xlabel('Volume Mixing Ratio', fontsize='large')
# Out:
# Text(0.5, 0, 'Volume Mixing Ratio')

# %%
from starships.plotting_fcts import _get_fig_and_ax_inputs, _get_idx_in_range, colorsDict, defaultColorsOrder

def plot_profile_combined(pressures, stats_list, p_range=(1e-6, 1e2), stats_keys=('1-sig', '2-sig'),
                          fig=None, ax=None, tight_range=True, colorsOrder=None):


    # Make sure there is a pressure array for each stats
    n_profiles = len(stats_list)
    if len(pressures) != n_profiles:
        pressures = [pressures for _ in range(n_profiles)]
    # Rename
    pressure_list = pressures
    
    if p_range is None:
        p_range = (np.min(pressure_list), np.max(pressure_list))
    
    # Use default color order from pyGTC
    if colorsOrder is None:
        colorsOrder = list(defaultColorsOrder[:n_profiles])

    # Get pressure index
    pressure_idx_list = [_get_idx_in_range(press, p_range) for press in pressure_list]

    
    # Plot starts here

    # Init figure and axes if needed
    fig, ax = _get_fig_and_ax_inputs(fig, ax)

    # Get colors and assign for each statistic in sample_stats (so each key)
    color_region = [dict() for _ in range(n_profiles)]
    # and assign for each statistic in sample_stats (so each key)
    for idx_pro, cs in enumerate(colorsOrder):
        stats = stats_list[idx_pro]
        for idx_stat, key in enumerate(stats_keys):
            try:
                color_region[idx_pro][key] = colorsDict[cs][idx_stat]
            except IndexError:
                raise IndexError(f"To many satistics to plot for available colors (length = {len(defaultColorsOrder)})")

    handles_for_legend = []
    for idx_pro in reversed(range(n_profiles)):
        stats = stats_list[idx_pro]
        color_pro = color_region[idx_pro]
        pressures = pressure_list[idx_pro]
        idx_p = pressure_idx_list[idx_pro]
        for key in reversed(stats_keys):
            x1, x2 = stats[key]
            handles = ax.fill_betweenx(pressures[idx_p], x1[idx_p], x2[idx_p], color=color_pro[key])
        handles_for_legend.append(handles)

    for idx_pro in reversed(range(1, n_profiles)):
        stats = stats_list[idx_pro]
        color_pro = color_region[idx_pro]
        pressures = pressure_list[idx_pro]
        idx_p = pressure_idx_list[idx_pro]
        for key in reversed(stats_keys):
            x1, x2 = stats[key]
            ax.plot(x1[idx_p], pressures[idx_p], '-', color=color_pro[key])
            ax.plot(x2[idx_p], pressures[idx_p], '-', color=color_pro[key])

    if tight_range:
        all_p = [pressures[idx_p] for pressures, idx_p in zip(pressure_list, pressure_idx_list)]
        ax.set_ylim(np.min(all_p), np.max(all_p))

    ax.set_yscale('log')    

    ylim = ax.get_ylim()
    if ylim[-1] > ylim[0]:
        ax.invert_yaxis()

    ax.set_ylabel('Pressure [bar]', fontsize=16)
    
    return fig, ax, list(reversed(handles_for_legend))

# %%
# %matplotlib inline

# %%
species_compared = None #['CO']

if species_compared is None:
    species_compared = [specie for specie in profile_stats
                        if specie in profile_stats_eq]

n_species = len(species_compared)
fig, ax = plt.subplots(1, n_species + 1, sharey=True, figsize=(3 * n_species, 4))

for ax_i, specie in zip(ax, species_compared):
    _, _, handles = plot_profile_combined(pressures, [profile_stats_eq[specie], profile_stats[specie]], ax=ax_i)
    ax_i.set_xscale('log')
    ax_i.set_title(specie)
    ax_i.set_ylabel(None)

# Add a legend beside the panels
ax[-1].axis('off')
# Position of the text
xpos = 0.1
ypos = 0.9
d_ypos = -0.1
for handle, label in zip(handles, ['Equilibrium', 'Free']):
    color = handle.get_facecolor()[0]
    ax[-1].text(xpos, ypos, label, color=color, fontsize=16, transform=ax[-1].transAxes)
    ypos += d_ypos

ax[0].set_ylabel('Pressure [bar]', fontsize='large')
ax[n_species // 2].set_xlabel('Volume Mixing Ratio', fontsize='large')
# Out:
# <img src="data:image/png;base64,..." width="3900">
# Text(0.5, 0, 'Volume Mixing Ratio')

# %% [markdown]
# # Show the model for specific parameters

# %% [markdown]
# ## Generate/initialize the model

# %% [markdown]
# ### Choose which parameters you want (best logL?, median?)
# TIP: Look at the logL plot to see which one represents the best your results

# %%
params_set = ord_pos_sub  # Sub sample defined above
# params_set = ord_pos  # full sample

best_params = params_set[-1]  # Best logl
# best_params = params_set[len(params_set) // 2]  # Median

print(best_params)
# Out:
# [ -2.3479507   -4.40230224 320.1070873   19.57800829   0.57105812
#   -1.42271593 146.9752757   -2.65340719   1.62281344 -14.73137873
#    5.67910512   0.98071546   0.83851379]

# %%
# hand picked best params
# best_params = np.array([-1.,-4.5, 600, -5.8, 0.975, 0.63])

# %% [markdown]
# ### Convert the parameters array to a dictionary of parameters

# %% [markdown]
# Note: `theta_regions` is a list of dictionnaries with all potential parameters that could be useful. You can edit it here if you  want before generating the model.
#
# - Each dictionary represent a specific region on the planet (so usually just one region)

# %%
theta_regions = retrieval.unpack_theta(best_params)

# %%
# Print some values from region #1
_ = [print(key, theta_regions[0][key]) for key in retrieval.params_prior]
# Out:
# H2O 0.004487963337241807
# CH4 3.960023490687408e-05
# T_eq 320.1070873038997
# T_int 19.5780082880471
# tp_gamma 3.7244154514586483
# kappa_IR 0.03778192420540531
# kp 146.97527570370897
# rv -2.65340718895576
# p_cloud 41.95787107639489
# gamma_scat -14.731378734194198
# scat_factor 477644.8776647192
# R_pl 7011330942.158324
# cloud_fraction 0.8385137947237065

# %% [markdown]
# ### Compute the spectrum (first time is slower due to initialization)
# NOTE: We compute the spectrum with the 2 possible methods in petitRADTRANS (line-by-line and correlated-k) to make sure they are consistent. Correlated-k (c-k) is used for the fit only if the low-resolution observations (spectrophotometry or photometry) is not completely covered by the high-res spectrum.

# %%
wv_high, spec_high = retrieval.prepare_model_multi_reg(theta_regions, 'high')
# Out:
# INFO:starships.retrieval:Model not initialized for mode = high and range [0.9, 1.98]. Starting initialization...
# INFO:starships.petitradtrans_utils:['H2O_pokazatel_main_iso', 'CH4_Hargreaves_main_iso']
# /home/fgenest/starships_env/lib/python3.9/site-packages/petitRADTRANS/radtrans.py:100: FutureWarning: pRT_input_data_path was set by an environment variable. In a future update, the path to the petitRADTRANS input_data will be set within a .ini file that will be automatically generated into the user home directory (OS agnostic), inside a .petitradtrans directory
#   warnings.warn(f"pRT_input_data_path was set by an environment variable. In a future update, the path to "
#   Read line opacities of H2O_pokazatel_main_iso...
#  Done.
#   Read line opacities of CH4_Hargreaves_main_iso...
#  Done.
#
#   Read CIA opacities for H2-H2...
# INFO:starships.petitradtrans_utils:Generating atmosphere with pressures from 100.0 to 1e-10
# INFO:starships.petitradtrans_utils:You are not getting the individual contributions of the species
# INFO:starships.retrieval:Saving values in `linelist_names`.
# INFO:starships.retrieval:Star spectrum not initialized for mode = high. Starting initialization...
# INFO:starships.retrieval:No stellar spectrum provided. A blackbody at Teff will be used.
#   Read CIA opacities for H2-He...
# Done.

# %%
wv_low, spec_low = retrieval.prepare_model_multi_reg(theta_regions, 'low')
# Out:
# INFO:starships.retrieval:Model not initialized for mode = low and range [0.9, 4.156887500000001]. Starting initialization...
# INFO:starships.petitradtrans_utils:['H2O_HITEMP', 'CH4']
#   Read line opacities of H2O_HITEMP...
#  Done.
#   Read line opacities of CH4...
#  Done.
#
#   Read CIA opacities for H2-H2...
# INFO:starships.petitradtrans_utils:Generating atmosphere with pressures from 100.0 to 1e-10
# INFO:starships.petitradtrans_utils:You are not getting the individual contributions of the species
# INFO:starships.retrieval:Saving values in `linelist_names`.
# INFO:starships.retrieval:Star spectrum not initialized for mode = low. Starting initialization...
# INFO:starships.retrieval:No stellar spectrum provided. A blackbody at Teff will be used.
#   Read CIA opacities for H2-He...
# Done.

# %%
plt.plot(wv_high, spec_high*1e6)
plt.plot(wv_low, spec_low*1e6)

# %% [markdown]
# #### You can save the spectrum if you want to use it for other purpose.

# %%
save_spectrum = False
dir_spectra = Path.home() / Path('VSCodeProjects/starships_analysis/WASP-33b/Spectra')
file_stem = 'take3_HRR_modif_disso_31254924'
# file_stem = retrieval.walker_file_out.stem.split('walker_steps_')[-1]

# %%
if save_spectrum:
    filename = f'{file_stem}_all.npz'
    print('Saving', filename)
    np.savez(dir_spectra / filename, wave=wv_high, spec=spec_high)

# %% [markdown]
# ### Show the spectrum for each individual specie (line opacity)
# (Again can be useful to perform cross-correlations for example)

# %%
# %matplotlib inline

# %%
dir_spectra = Path.home() / Path('VSCodeProjects/starships_analysis/WASP-33b/Spectra')

for single_mol in retrieval.line_opacities:
    
    # Copy input dict
    theta_reg_single = [dict(theta_dict) for theta_dict in theta_regions]
    
    # Set all other linelists to zero (10^-99 to avoid division by zero)
    for theta_dict in theta_reg_single:
        for mol in retrieval.line_opacities:
            if mol != single_mol:
                theta_dict[mol] = 1e-99
    
    wv_high, spec_high = retrieval.prepare_model_multi_reg(theta_reg_single, 'high')
    plt.plot(wv_high, spec_high, label=f'{single_mol} only', alpha=0.3)
    
    if save_spectrum:
        dir_spectra.mkdir(exist_ok=True)
        filename = f'{file_stem}_{single_mol}_only.npz'
        print('Saving spectrum to:', filename)
        np.savez(dir_spectra/filename, wave=wv_high, spec=spec_high)

plt.legend()

# %% [markdown]
# ## Quick comparison with spectrophotometric data
# All the data available in the yaml file is plotted, but it may not have been included in the fit.
# Ex: if you were using HRR mode.

# %%
from starships.plotting_fcts import get_plot_limits_from_data

# %%
# Get model spectra
wv_high, spec_high = retrieval.prepare_model_multi_reg(theta_regions, 'high')
wv_low, spec_low = retrieval.prepare_model_multi_reg(theta_regions, 'low')

# Make synthetic data for all low-res instruments
synt_data_dict = ru.get_syntetic_data_low_res(wv_low, spec_low, wv_high, spec_high, retrieval_obj=retrieval)

# %%
# %matplotlib inline

# %%
n_subplots = len(retrieval.spectrophotometric_data) + 1
fig, ax = plt.subplots(n_subplots, 1, figsize=(6, 3*n_subplots))

jwst_offset = 0

# Plot the model in each panel and set labels
for ax_i in ax:
    ax_i.plot(wv_high, spec_high * 1e6)#, label='lbl')
    ax_i.plot(wv_low, spec_low * 1e6)#, label="c-k")
    ax_i.set_ylabel(f"{retrieval.kind_trans} spectrum [ppm]")

# Make one panel per spectrophotmetric instrument name
for i_instru, (instru_name, infos) in enumerate(retrieval.spectrophotometric_data.items()):
    
    x_plot, y_plot, yerr = infos['wave'], infos['data'], infos['err']
    y_plot = y_plot * 1e6 + jwst_offset # in ppm
    yerr = yerr * 1e6  # in ppm
    
    # Force the plot limits around the low-res data
    xlim = get_plot_limits_from_data(x_plot)
    ylim = get_plot_limits_from_data(y_plot, pad=0.2)
    
    # Plots
    ax[i_instru].errorbar(x_plot, y_plot, yerr=yerr, fmt=".", label=instru_name)
    ax[i_instru].plot(x_plot, synt_data_dict[instru_name]*1e6, '.', label='Model binned')
    ax[i_instru].set_xlim(xlim)
    ax[i_instru].set_ylim(ylim)
    
    # Also plot in the last panel
    ax[-1].errorbar(x_plot, y_plot, yerr=yerr, fmt=".", label=instru_name)
    
    # Labels
    ax[i_instru].set_title(f"Zoom on {instru_name} data", loc='left')
    ax[i_instru].legend()


# Put everything in the last panel
for instru_name, infos in retrieval.photometric_data.items():
    
    x_plot, y_plot, yerr, x_limits = (infos[key] for key in ['wave', 'data', 'err', 'wv_coverages'])
    y_plot = y_plot * 1e6 # in ppm
    yerr = yerr * 1e6  # in ppm

    xerr = np.abs(np.transpose(x_limits) - x_plot)
    ax[-1].errorbar(x_plot, y_plot, yerr=yerr, xerr=xerr, fmt=".", label=instru_name)
    ax[-1].plot(x_plot, synt_data_dict[instru_name]*1e6, '.', label=f'Synt data ({instru_name})')


ax[-1].set_title(f"All data", loc='left')
ax[-1].set_xlabel("Wavelength [um]")
ax[-1].legend()
plt.tight_layout()

# path_fig = Path.home() / 'nirps/retrievals/plots/WASP-80b'
path_fig = Path.home() / 'nirps/figures/WASP-80b/CRAQ_2025'
plt.savefig(path_fig / f'{walker_file.name[:-3]}_jwst_model_comparison.pdf')

# %% [markdown]
# ## Isolate the contribution of each species

# %%
specie_list = retrieval.line_opacities #['H2O', 'TiO', 'VO', 'FeH', 'OH', 'CO', 'H-']
wv, spec_dict = ru.get_contribution(specie_list, retrieval, theta_regions, mode='low')

# %%
fig, ax = plt.subplots(6, 1 ,sharex=True, figsize=(8, 16))

for key, spec in spec_dict.items():
    if 'only' in key:
        ax[3].plot(wv, spec, label=key)
        spec = spec - spec_dict['No Species']
        ax[4].plot(wv, spec * 1e6, label=key)
        
        spec = spec / spec_dict['No Species']
        ax[5].plot(wv, spec, label=key)
    else:
        ax[0].plot(wv, spec * 1e6, label=key)
        if 'Without' in key:
            spec = spec_dict['All'] - spec
            ax[1].plot(wv, spec * 1e6, label=key)
            spec = spec / spec_dict['No Species']
            ax[2].plot(wv, spec * 1e6, label=key)
    
ax[0].set_ylabel(f"{retrieval.kind_trans} spectrum [ppm]")
# ax[3].set_ylabel('Difference (Specie - No Species) [ppm]')
# ax[4].set_ylabel('Relative to continuum (difference / No Specie)')

for ax_i in ax:
    ax_i.legend()

ax[1].set_xlim(2.4, 4.2)
# Out:
# (2.4, 4.2)

# %%
specie_list = [['Fe','H2O', 'OH', 'H-'], ['Fe','H2O', 'H-'], ['Fe','OH', 'H-'], ['OH','H2O', 'H-']]
wv, spec_dict = ru.get_contribution(specie_list, retrieval, theta_regions, mode='high')

# %%
# %matplotlib inline

# %%
fig, ax = plt.subplots(6, 1 ,sharex=True, figsize=(8, 16))

for key, spec in spec_dict.items():
    if 'only' in key:
        ax[3].plot(wv, spec, label=key)
        spec = spec - spec_dict['No Species']
        ax[4].plot(wv, spec * 1e6, label=key)
        
        spec = spec / spec_dict['No Species']
        ax[5].plot(wv, spec, label=key)
    else:
        ax[0].plot(wv, spec * 1e6, label=key)
        if 'Without' in key:
            spec = spec_dict['All'] - spec
            ax[1].plot(wv, spec * 1e6, label=key)
            spec = spec / spec_dict['No Species']
            ax[2].plot(wv, spec * 1e6, label=key)
    
ax[0].set_ylabel(f"{retrieval.kind_trans} spectrum [ppm]")
# ax[3].set_ylabel('Difference (Specie - No Species) [ppm]')
# ax[4].set_ylabel('Relative to continuum (difference / No Specie)')

for ax_i in ax:
    ax_i.legend()

# ax[1].set_xlim(0.8, 2.)

# %%
for key, spec in spec_dict.items():

    if 'only' in key:

        if save_spectrum:
            dir_spectra.mkdir(exist_ok=True)
            # Remove + and spaces
            extension = key.replace('+', '').split()
            extension = '_'.join(extension)
            filename = f'{file_stem}_{extension}.npz'
            print('Saving spectrum to:', filename)
            np.savez(dir_spectra/filename, wave=wv, spec=spec)
# Out:
# Saving spectrum to: take3_HRR_modif_disso_31254924_Fe_H2O_OH_H-_only.npz
# Saving spectrum to: take3_HRR_modif_disso_31254924_Fe_H2O_H-_only.npz
# Saving spectrum to: take3_HRR_modif_disso_31254924_Fe_OH_H-_only.npz
# Saving spectrum to: take3_HRR_modif_disso_31254924_OH_H2O_H-_only.npz

# %% [markdown]
# ## Compare line opacities (low VS high)
# **This is a good check to make when doing Joint Retrievals (JR)**
# (but it generating the high res spectra can take a lot of time, so don't do this everytime)

# %%
specie_list = [[mol, 'H-'] for mol in retrieval.line_opacities]
wv_high, spec_dict_high = ru.get_contribution(specie_list, retrieval, theta_regions, mode='high')
wv_low, spec_dict_low = ru.get_contribution(specie_list, retrieval, theta_regions, mode='low')

# %%
n_species = len(specie_list)

fig, ax = plt.subplots(n_species, 1 ,sharex=True, figsize=(8, n_species*2.7))

for idx, specie in enumerate(specie_list):
    specie_label = ' + '.join(specie)
    ax[idx].plot(wv_high, spec_dict_high[f'{specie_label} only'], label=f'{specie_label} high')
    
for idx, specie in enumerate(specie_list):
    specie_label = ' + '.join(specie)
    ax[idx].plot(wv_low, spec_dict_low['All'], label='All')
    ax[idx].plot(wv_low, spec_dict_low[f'{specie_label} only'], label=f'{specie_label} low')
    ax[idx].legend()
