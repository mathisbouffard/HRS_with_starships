# %%
import os
from astropy.io import fits

fits_file = "/home/mathisb/Github/HRS_data/SPIRou/TRAPPIST-1/2665330o_pp_e2dsff_AB.fits"
# data_directory = "/home/mbouffard/Research/Github/HRS_data/WASP_178_b/NIRPS_genevaHE_2023apr02/data" + "/"

with fits.open(fits_file) as fitsObject:
    hdr = fitsObject[0].header
    print(repr(hdr))
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILENAME= '2665330o'           / filename anticipated by fitspipe server
# PATHNAME= '/data/sessions/spirou/21BQ11-Oct26' / Original directory name at acqu
# DATE    = '2021-10-27T06:03:28' / UTC Date of file creation
# HSTTIME = 'Tue Oct 26 20:03:28 HST 2021' / Local time in Hawaii
# IMAGESWV= 'DetCom-SPIRou v1.20 svn 13907 (compiled Aug 25 2020)' / Image creatio
# IMAGELBV= 'CFHT libdetcom v1.10 svn 13902 (compiled Aug 25 2020)' / Image creati
# RAMPSWV = 'fitspipe v2.12 (Jul 26 2018)' / RAMP fitting software version
# OBSTYPE = 'OBJECT  '           / Observation / Exposure type
# EXPTYPE = 'OBJECT  '           / See OBSTYPE
# EXPREQ  =              512.617 / [sec] Requested integration time
# EXPTIME =              512.617 / [sec] Integration time
# INTTIME =              512.617 / See EXPTIME
# DARKTIME=              518.189 / [sec] Dark current time
# FRMTIME =              5.57192 / [sec] Frame time, cadence of IR reads
# NRESETS =                    1 / Number of resets before integration
# NREADS  =                   93 / Number of reads in ramp sequence
# HXRGVER = 'Not IDL '           / HXRG IDL software version number
# FASTMODE=                    0 / SlowMode=0,FasMode=1
# NEXTRAP =                    0 / Number of extral pixels per row
# NEXTRAL =                    0 / Number of extral line per frame
# REFOUT  =                    0 / Reference output.0 disabled; 1 enabled with ref
# REFPIXEL=                    0 / Interleave reference pixel mode. 0 disabled
# ASIC_NUM= '156     '           / ASIC serial number
# SCA_ID  = 'C001    '           / SCA number
# MUXTYPE =                    4 / 1- H1RG; 2- H2RG; 4- H4RG
# NOUTPUTS=                   32 / Number of detector outputs
# NADCS   =                    1 / Number of averaged ADCs used per output
# PDDECTOR=                    0 / Power down detector
# CLKOFF  =                    0 / Turn off clocks
# WARMTST =                    0 / 0- cold test; 1- warm test
# CLOCKING=                    1 / 0- normal clocking; 1- enhanced horizonal clock
# GLBRESET=                    0 / 0- pixel-by-pixel or line-by-line rest; 1- glob
# FRMODE  =                    0 / 0- full frame mode; 1- window mode
# CAMLINK =                    0 / If Camlink readout enabled (1 enabled)
# EXPMODE =                    0 / 0- Ramp mode; 1- Fowler sampling mode
# MCLK    =              10.0000 / MHz. Master Clock
# ACQTYPE =                    2 / Dark Current Ramp Sequence(2)
# DATAMODE=                    5 / Parallel read, 8 bit bus, 16 bit data
# DATLEVEL=                    1 / 0- CMO; 1- LVDS
# ASICGAIN=                   12 / 12 (18dB large Cin)
# NOMGAIN =                   12 / 12 (18dB large Cin)
# AMPRESET=                    0 / 0- Reset once per frame; 1- Reset once per row
# KTCREMOV=                    0 / 0- No kTC Removal; 1- kTC Removal
# SRCCUR  =                    0 / 0-No source current to inp ; 1 - Source current
# AMPINPUT=                    1 / 0- VREFMAIN as ref; 1- InPCommon as ref; 2- use
# SATURATE=                60000 / Saturation value (ADU)
# GAIN    =                0.999 / Amplifier gain (electrons/ADU)
# RDNOISE =                 10.9 / Read noise (electrons)
# INSTRUME= 'SPIRou  '           / Instrument Name
# CMMTOBS = 'N/A     '
# CMMTSEQ = 'I exposure 1 of 16'
# OBJECT  = 'TRAPPIST-1'
# OBSERVER= 'QSO Team'
# PI_NAME = 'Xavier Bonfils'
# RUNID   = '21BF16  '
# EXPNUM  =              2665330 / CFHT odometer number
# OBSID   =              2665330 / See EXPNUM
# CMPLTEXP=                    1 / Exposure number within the exposure sequence
# NEXP    =                   16 / Total number of exposures within the sequence
# TELESCOP= 'CFHT 3.6m'          / Hawaii Big Island, Mauna Kea
# ORIGIN  = 'CFHT    '           / Canada-France-Hawaii Telescope
# LATITUDE=            19.825252 / Latitude (degrees N)
# LONGITUD=          -155.468876 / Longitude (degrees E)
# TELSTAT = 'auto_guide'         / Telescope Control System status
# TIMESYS = 'UTC     '           / Time System for DATExxxx and TIMExxxx
# DATE-OBS= '2021-10-27'         / Date at start of observation (UTC)
# UTIME   = '5:54:34.99'         / Time at start of observation (UTC)
# UTC-OBS = '5:54:34.99'         / Time at start of observation (UTC)
# MJDATE  =        59514.2462383 / Modified Julian Date at start of observation
# MJD-OBS =        59514.2462383 / Modified Julian Date at start of observation
# SIDTIME = '21:55:59.27'        / Sidereal time at start of observation
# LST-OBS = '21:55:59.27'        / Sidereal time at start of exposure
# DATEEND = '2021-10-27'         / Date at end of observation (UTC)
# UTCEND  = '6:03:26.46'         / Time at end of observation (UTC)
# MJDEND  =        59514.2523896 / Modified Julian Date at end of observation
# LSTEND  = '22:04:52.19'        / Sidereal time at end of exposure
# EQUINOX =               2000.0 / Equinox of coordinates
# RADECSYS= 'FK5     '           / Coordinate system for equinox (FK4/FK5/GAPPT)
# RA      = '23:06:30.75'        / Telescope right ascension
# DEC     = '-5:02:39.5'         / Telescope declination
# HA      = '-1:10:31.48'        / Telescope hour angle at start of exposure
# HAEND   = '-1:01:38.56'        / Telescope hour angle at end of exposure
# INSTZRA =                 0.00 / Instrument zero for RA in arc seconds
# INSTZDEC=                 0.00 / Instrument zero for Dec in arc seconds
# RA_DEG  =           346.628125 / Telescope right ascension in degrees
# DEC_DEG =            -5.044306 / Telescope declination in degrees
# OBJNAME = 'TRAPPIST-1'         / Target name
# OBJMAG  =                10.72 / Object magnitude
# OBJEQUIN=               2000.0 / Target equinox
# OBJRADEC= 'FK5     '           / Coordinate system for equinox (FK4/FK5/GAPPT)
# OBJRA   = '23:06:30.75'        / Target right ascension
# OBJDEC  = '-5:02:39.5'         / Target declination
# OBJRAPM =                 0.93 / Target right ascension proper motion in as/yr
# OBJDECPM=                -0.48 / Target declination proper motion in as/yr
# NGUIDER =                    1 / TCS Number of guiders
# NGUISTAR=                    1 / TCS number of guide stars/probes in use
# GUINAME = 'Cass    '           / TCS guider name
# GUIEQUIN=              2021.82 / TCS guider equinox
# GUIRADEC= 'GAPPT   '           / TCS guider system for equinox
# GUIRA   = '0:00:00.00'         / TCS guider right ascension
# GUIDEC  = '0:00:00.0'          / TCS guider declination
# GUIRAPM =                 0.00 / TCS guider right ascension proper motion arcsec
# GUIDECPM=                 0.00 / TCS guider declination proper motion arcsec
# GUIOBJN = 'Null    '           / TCS guider object name
# GUIMAGN =              -9999.9 / TCS guider object magnitude
# XPROBE  =             -201.000 / Telescope bonnette guide probe X position
# YPROBE  =                5.000 / Telescope bonnette guide probe Y position
# ZPROBE  =              374.000 / Telescope bonnette guide probe Z position
# GUIFLUX =                -9999 / TCS guider flux
# GUIFWHX =             -9999.90 / TCS guider average x FWHM in pixels
# GUIFWHY =             -9999.90 / TCS guider average y FWHM in pixels
# SKYFLUX =                -9999 / TCS total sky flux
# AIRMASS =                1.159 / Airmass at start of observation
# TELALT  =              59.6154 / Telescope altitude at start of observation, deg
# TELAZ   =             142.7510 / Telescope azimuth at start, deg, 0=N 90=E 270=W
# DOMEAZ  =                142.4 / Dome azimuth at start, deg, 0=N 90=E 270=W
# MOONANGL=               120.80 / Angle from object to moon at start in degrees
# MOONPHAS=                -0.63 / Moon phase @ 0 HST, 0..1 new>full, -1..0 >new
# MOONUP  = 'False   '           / Moon up? True or False
# MOONALT =               -30.20 / Moon altitude at start in degrees
# MOONAZ  =                42.30 / Moon azimuth at start in deg, 0=N 90=E 270=W
# FOCUSID = 'Cass    '           / Telescope focus in use
# TELCONF = 'Cass    '           / Telescope focus in use
# CALFOCUS=               13.540 / Telescope focus calculated from model in mm
# DEFOCUS =                0.000 / Telescope defocus from calculated in mm
# FOCUSPOS=                13541 / Telescope focus encoder readout in microns
# TELFOCUS=                13541 / Telescope focus encoder readout in microns
# BONANGLE=                 0.06 / Telescope bonnette rotation angle in degrees
# ROTANGLE=                 0.06 / Telescope bonnette rotation angle in degrees
# TCSGPSBC= '0072 05:54:31.275619' / TCS GPS read out in BCD
# TCSGPSTM=              5.90869 / TCS GPS clock time in decimal hours
# TCSRBUSS= '18:05:00.000'       / TCS RBUSS clock time
# TCSEPICS= '20211027 05:53:27.281' / TCS EPICS clock time
# TCSAMODE= 'O       '           / TCS acquire mode - T/O/G/g/P for t/o/g coords
# TCSMJD  =        59514.2461949 / TCS MJD
# TCSLST  =             21.93209 / TCS LST in decimal hours
# TCSAPHA =            -17.92813 / TCS apparent hour angle in degrees
# TCSAPDEC=             -4.92659 / TCS apparent declination in degrees
# TCSOBHA =            -17.92486 / TCS observed hour angle in degrees
# TCSOBDEC=             -4.92169 / TCS observed declination in degrees
# TCSENHA =                    0 / TCS hour angle absolute encoder in bits
# TCSENDEC=                    0 / TCS declination absolute encoder in bits
# TCSEDHA =            -17.90949 / TCS hour angle absolute encoder in degrees
# TCSEDDEC=             -4.94115 / TCS declination absolute encoder in degrees
# TCSINHA =                  -17 / TCS hour angle incremental encoder in bits
# TCSINDEC=                   -4 / TCS declination incremental encoder in bits
# TCSSEHA =                -0.06 / TCS hour angle servo error in arcsec
# TCSSEDEC=                 0.10 / TCS declination servo error in arcsec
# TCSGEHA =                 0.00 / TCS hour angle guider error in arcsec
# TCSGEDEC=                 0.00 / TCS declination guider error in arcsec
# TCSPMHA =              360.063 / TCS hour angle pointing model output in arcsec
# TCSPMDEC=               94.716 / TCS declination pointing model output in arcsec
# TCSAMHA =                0.000 / TCS hour angle encoder model in arcsec
# TCSAMDEC=               12.401 / TCS declination encoder model in arcsec
# TCSVMHA =                0.000 / TCS hour angle virtual encoder model in arcsec
# TCSVMDEC=                0.000 / TCS declination virtual encoder model in arcsec
# TCSCREEP=                0.000 / TCS declination creep model in arcsec
# TCSMVRA =              -2.6100 / TCS right ascension acquisition move in arcsec
# TCSMVDEC=             -14.4200 / TCS declination acquisition move in arcsec
# TCSMVX  =            -9999.900 / TCS secondary guider acquisition x move in mm
# TCSMVY  =            -9999.900 / TCS secondary guider acquisition y move in mm
# SB_ADC_S= 'ON      '           / SPIRou ADC tracking state (on/off)
# SBADC1_P=                356.6 / SPIRou ADC 1 angle at start of exp (degrees)
# SBADC2_P=                425.3 / SPIRou ADC 2 angle at start of exp (degrees)
# SBCALI_P= 'P5      '           / SPIRou calibwh predefined position or angle
# SBDENS_P=                  0.0 / SPIRou guiding density at start of exp
# SBRHB1_P= 'P16     '           / SPIRou rhomb 1 predefined position or angle
# SBRHB2_P= 'P16     '           / SPIRou rhomb 2 predefined position or angle
# SBETEM_P= 'P2      '           / SPIRou eecalibpk predefined position or angle
# SB_INJ_T=                 4.78 / SPIRou tinject temp at start of exp (deg C)
# SB_POL_T=                 2.17 / SPIRou tpolar temp at start of exp (deg C)
# SB_CS1_T=             -9999.00 / SPIRou tcoldstop 1 temp at start of exp (deg C)
# SB_CS2_T=             -9999.00 / SPIRou tcoldstop 2 temp at start of exp (deg C)
# SB_CB1_T=                 4.41 / SPIRou tcabinet 1 temp at start of exp (deg C)
# SB_CB2_T=                10.03 / SPIRou tcabinet 2 temp at start of exp (deg C)
# SBIAVL1S= 'OFF     '           / SPIRou injection LED status (on/off)
# SBIAVL2S= 'OFF     '           / SPIRou fiber LED status (on/off)
# SBETEL_S= 'OFF     '           / SPIRou end to end halogen light status (on/off)
# SB_CSC_S= 'OFF     '           / SPIRou coldstop cell status (On / Off)
# SEADC1_P=                360.7 / SPIRou ADC 1 angle at end of exp (degrees)
# SEADC2_P=                422.5 / SPIRou ADC 2 angle at end of exp (degrees)
# SEDENS_P=                  0.0 / SPIRou guiding density at end of exp
# SE_INJ_T=                 4.75 / SPIRou tinject temp at end of exp (deg C)
# SE_POL_T=                 3.59 / SPIRou tpolar temp at end of exp (deg C)
# SE_CS1_T=             -9999.00 / SPIRou tcoldstop 1 temp at end of exp (deg C)
# SE_CS2_T=             -9999.00 / SPIRou tcoldstop 2 temp at end of exp (deg C)
# SE_CB1_T=                 4.74 / SPIRou tcabinet 1 temp at end of exp (deg C)
# SE_CB2_T=                10.15 / SPIRou tcabinet 2 temp at end of exp (deg C)
# SBCREF_P= 'pos_pk  '           / SPIRou Reference Fiber Position (predefined)
# SBCCAS_P= 'pos_pk  '           / SPIRou Cassegrain Fiber Position (predefined)
# SBCDEN_P=                 3.03 / SPIRou Calib-Reference density (0 to 3.3)
# SBAGIT_S= 'ON      '           / SPIRou fiber agitator state (On, Off)
# SBAGITCS= 'OFF     '           / SPIRou fiber agitator state at Cass (On, Off)
# SBCMIR_P= 'cold    '           / SPIRou Mirror Position (predefined)
# SBCLHC1S= 'OFF     '           / SPIRou Hollow Cathod Lamp#1 Status
# SBCLHC1W= 'OFF     '           / SPIRou Hollow Cathod Lamp#1 Warming State
# SBCLHC1C=                  0.0 / SPIRou Hollow Cathod Lamp#1 Current (mA)
# SBCLHC2S= 'OFF     '           / SPIRou Hollow Cathod Lamp#2 Status
# SBCLHC2W= 'OFF     '           / SPIRou Hollow Cathod Lamp#2 Warming State
# SBCLHC2C=                  0.0 / SPIRou Hollow Cathod Lamp#2 Current (mA)
# SBCLWL_S= 'OFF     '           / SPIRou White Lamp Status (On, Off, Err)
# SBCLWL_C=                  0.0 / SPIRou White Lamp Current (mA)
# SBWLSH_S= 'CLOSED  '           / SPIRou White Lamp Shutter State (open, closed)
# SBCTEC_S= 'ON      '           / SPIRou ColdSource Status (On, Off, Err)
# SBCTECCT=               -25.00 / SPIRou ColdSource Cold Face Temp (deg C)
# SBCTECHT=                 8.25 / SPIRou ColdSource Hot Face Temp (deg C)
# SBCCPRIT=                 6.91 / SPIRou Cold plate Reg Input Temp (deg C)
# SBCCCU_T=                18.68 / SPIRou Control Unit Temperature (deg C)
# SBCCPROT=                 7.52 / SPIRou Cold plate Reg Output Temp (deg C)
# SBCFBI_T=                 7.30 / SPIRou Flux Balance Input Temp (deg C)
# SBCWLS_T=                 9.42 / SPIRou White Lamp slot Temp (deg C)
# SBCLSUAT=                10.86 / SPIRou Lamps Selection Unit Ambient Temp (deg C
# SBCREG_S= 'ON      '           / SPIRou Cold Plates Regulation Status (Off, On)
# SBCCPT_T=                 7.00 / SPIRou Cold Plates Target Temp (deg C)
# SBCCPB_T=                 6.21 / SPIRou Cold Plates Bath Temp (deg C)
# SBCFPI_T=               20.001 / SPIRou Fabry Perot Internal Temp: FPBody(deg C)
# SBCFPE_T=               20.004 / SPIRou Fabry Perot External Temp: FPCase(deg C)
# SBCFPB_P=                0.288 / SPIRou Fabry Perot Internal Pressure (mbar)
# SBCFPP_V=               65.400 / SPIRou Fabry Perot Heater Power (%)
# SBCFPR_S= 'LOW     '           / SPIRou Fabry Perot Heater Range
# SECTECCT=               -24.85 / SPIRou ColdSource Cold Face Temp (deg C)
# SECTECHT=                 8.18 / SPIRou ColdSource Hot Face Temp (deg C)
# SECCPRIT=                 6.91 / SPIRou Cold plate Regulation Input Temp (deg C)
# SECCCU_T=                18.63 / SPIRou Control Unit Temp (degree C)
# SECCPROT=                 7.47 / SPIRou Cold plate regulation output Temp (deg C
# SECFBI_T=                 7.23 / SPIRou Flux Balance Input Temp (deg C)
# SECWLS_T=                 9.33 / SPIRou White Lamp slot Temp (deg C)
# SECLHC1C=                  0.0 / SPIRou Hollow Cathod Lamp#1 Current (mA)
# SECLHC2C=                  0.0 / SPIRou Hollow Cathod Lamp#2 Current (mA)
# SECLWL_C=                  0.0 / SPIRou White Lamp Current (A)
# SECLSUAT=                 9.33 / SPIRou Lamps Selection Unit Ambient Temp (deg C
# SECREG_S= 'ON      '           / SPIRou Cold Plates Regulation Status (Off, On)
# SECCPT_T=                 7.00 / SPIRou Cold Plates Target Temp (deg C)
# SECCPB_T=                 6.20 / SPIRou Cold Plates Bath Temp (deg C)
# SECFPI_T=               20.002 / SPIRou Fabry Perot Internal Temp: FPBody (deg C
# SECFPE_T=               20.004 / SPIRou Fabry Perot External Temp: FPCase (deg C
# SECFPB_P=                0.288 / SPIRou Fabry Perot Internal Pressure (mbar)
# SECFPP_V=               65.400 / SPIRou Fabry Perot Heater Power (%)
# SECFPR_S= 'LOW     '           / SPIRou Fabry Perot Heater Range
# SBVGA_CP=             0.000600 / SPIRou Vacuum A CG Pressure at start (Torr)
# SBVGA_IP=             1.34E-06 / SPIRou Vacuum A IG Pressure at start (Torr)
# SBVGB_CP=             0.000600 / SPIRou Vacuum B CG Pressure at start (Torr)
# SBVGB_IP=             1.34E-06 / SPIRou Vacuum B IG Pressure at start (Torr)
# SBMK00_T=             73.50015 / SPIRou MicroK Temp #00 at start (deg K)
# SBMK01_T=             73.49969 / SPIRou MicroK Temp #01 at start (deg K)
# SBMK02_T=             73.50013 / SPIRou MicroK Temp #02 at start (deg K)
# SBMK03_T=             73.90275 / SPIRou MicroK Temp #03 at start (deg K)
# SBMK04_T=             73.62519 / SPIRou MicroK Temp #04 at start (deg K)
# SBMK05_T=             73.36954 / SPIRou MicroK Temp #05 at start (deg K)
# SBMK06_T=             73.51646 / SPIRou MicroK Temp #06 at start (deg K)
# SBMK07_T=             73.71056 / SPIRou MicroK Temp #07 at start (deg K)
# SBLS000T=              84.0252 / SPIRou Lakeshore 0 Temp #00 at start (deg K)
# SBLS001T=              77.5599 / SPIRou Lakeshore 0 Temp #01 at start (deg K)
# SBLS002T=              78.9012 / SPIRou Lakeshore 0 Temp #02 at start (deg K)
# SBLS003T=              77.9457 / SPIRou Lakeshore 0 Temp #03 at start (deg K)
# SBLS004T=              66.9829 / SPIRou Lakeshore 0 Temp #04 at start (deg K)
# SBLS005T=              43.9980 / SPIRou Lakeshore 0 Temp #05 at start (deg K)
# SBLS006T=              44.0052 / SPIRou Lakeshore 0 Temp #06 at start (deg K)
# SBLS007T=              55.7044 / SPIRou Lakeshore 0 Temp #07 at start (deg K)
# SBLS008T=             119.0630 / SPIRou Lakeshore 0 Temp #08 at start (deg K)
# SBLS009T=              77.0049 / SPIRou Lakeshore 0 Temp #09 at start (deg K)
# SBLS010T=              83.5063 / SPIRou Lakeshore 0 Temp #10 at start (deg K)
# SBLS011T=              85.9874 / SPIRou Lakeshore 0 Temp #11 at start (deg K)
# SBLS100T=              74.4023 / SPIRou Lakeshore 1 Temp #00 at start (deg K)
# SBLS101T=              74.4277 / SPIRou Lakeshore 1 Temp #01 at start (deg K)
# SBLS102T=              74.5078 / SPIRou Lakeshore 1 Temp #02 at start (deg K)
# SBLS103T=              74.6944 / SPIRou Lakeshore 1 Temp #03 at start (deg K)
# SBLS104T=              74.4713 / SPIRou Lakeshore 1 Temp #04 at start (deg K)
# SBLS105T=              80.9766 / SPIRou Lakeshore 1 Temp #05 at start (deg K)
# SBLS106T=              74.3817 / SPIRou Lakeshore 1 Temp #06 at start (deg K)
# SBLS107T=              74.4615 / SPIRou Lakeshore 1 Temp #07 at start (deg K)
# SBLS108T=             273.8190 / SPIRou Lakeshore 1 Temp #08 at start (deg K)
# SBLS109T=              89.9978 / SPIRou Lakeshore 1 Temp #09 at start (deg K)
# SBLS110T=              79.9923 / SPIRou Lakeshore 1 Temp #10 at start (deg K)
# SBLS111T=              85.6335 / SPIRou Lakeshore 1 Temp #11 at start (deg K)
# SBL00I_T=              73.5002 / SPIRou Loop #0 Temp at start (deg K)
# SBL00H_V=               27.731 / SPIRou Loop #0 Heater Output at start (%)
# SBL01I_T=              73.4997 / SPIRou Loop #1 Temp at start (deg K)
# SBL01H_V=               28.139 / SPIRou Loop #1 Heater Output at start (%)
# SBL02I_T=              73.5001 / SPIRou Loop #2 Temp at start (deg K)
# SBL02H_V=               26.514 / SPIRou Loop #2 Heater Output at start (%)
# SBL03I_T=              77.0049 / SPIRou Loop #3 Temp at start (deg K)
# SBL03H_V=                8.432 / SPIRou Loop #3 Heater Output at start (%)
# SBL04I_T=              84.0252 / SPIRou Loop #4 Temp at start (deg K)
# SBL04H_V=               12.907 / SPIRou Loop #4 Heater Output at start (%)
# SBL05I_T=              77.5599 / SPIRou Loop #5 Temp at start (deg K)
# SBL05H_V=               15.245 / SPIRou Loop #5 Heater Output at start (%)
# SBL06I_T=              78.9012 / SPIRou Loop #6 Temp at start (deg K)
# SBL06H_V=               15.239 / SPIRou Loop #6 Heater Output at start (%)
# SBL07I_T=              77.9457 / SPIRou Loop #7 Temp at start (deg K)
# SBL07H_V=               12.053 / SPIRou Loop #7 Heater Output at start (%)
# SBL08I_T=              79.9923 / SPIRou Loop #8 Temp at start (deg K)
# SBL08H_V=                1.130 / SPIRou Loop #8 Heater Output at start (%)
# SBL09I_T=              89.9978 / SPIRou Loop #9 Temp at start (deg K)
# SBL09H_V=                5.698 / SPIRou Loop #9 Heater Output at start (%)
# SBL10I_T=              43.9980 / SPIRou Loop #10 Temp at start (deg K)
# SBL10H_V=               44.762 / SPIRou Loop #10 Heater Output at start (%)
# SBL11I_T=              44.0052 / SPIRou Loop #11 Temp at start (deg K)
# SBL11H_V=               15.793 / SPIRou Loop #11 Heater Output at start (%)
# SBL12I_T=              85.9874 / SPIRou Loop #12 Temp at start (deg K)
# SBL12H_V=                4.843 / SPIRou Loop #12 Heater Output at start (%)
# SBL13I_T=              83.5063 / SPIRou Loop #13 Temp at start (deg K)
# SBL13H_V=                0.000 / SPIRou Loop #13 Heater Output at start (%)
# SBENVCRT=                11.88 / SPIRou Coude Room Temp at start (deg C)
# SBENVSRT=                13.60 / SPIRou Slit Room Temp at start (deg C)
# SBENVRUT=                10.88 / SPIRou WarmUp Rear Under Heater (deg C)
# SBENVFUT=                10.50 / SPIRou WarmUp Front Under Heater (deg C)
# SBENVROT=                11.12 / SPIRou WarmUp Rear Outside Heater (deg C)
# SBENVFOT=                10.88 / SPIRou WarmUp Front Outside Heater (deg C)
# SEVGA_CP=             0.000600 / SPIRou Vacuum A CG Pressure at end (Torr)
# SEVGA_IP=             1.34E-06 / SPIRou Vacuum A IG Pressure at end (Torr)
# SEVGB_CP=             0.000600 / SPIRou Vacuum B CG Pressure at end (Torr)
# SEVGB_IP=             1.34E-06 / SPIRou Vacuum B IG Pressure at end (Torr)
# SEMK00_T=             73.50008 / SPIRou MicroK Temp #00 at end (deg K)
# SEMK01_T=             73.50024 / SPIRou MicroK Temp #01 at end (deg K)
# SEMK02_T=             73.50009 / SPIRou MicroK Temp #02 at end (deg K)
# SEMK03_T=             73.90279 / SPIRou MicroK Temp #03 at end (deg K)
# SEMK04_T=             73.62478 / SPIRou MicroK Temp #04 at end (deg K)
# SEMK05_T=             73.36986 / SPIRou MicroK Temp #05 at end (deg K)
# SEMK06_T=             73.51591 / SPIRou MicroK Temp #06 at end (deg K)
# SEMK07_T=             73.71047 / SPIRou MicroK Temp #07 at end (deg K)
# SELS000T=              84.0246 / SPIRou Lakeshore 0 Temp #00 at end (deg K)
# SELS001T=              77.5587 / SPIRou Lakeshore 0 Temp #01 at end (deg K)
# SELS002T=              78.9028 / SPIRou Lakeshore 0 Temp #02 at end (deg K)
# SELS003T=              77.9445 / SPIRou Lakeshore 0 Temp #03 at end (deg K)
# SELS004T=              66.9831 / SPIRou Lakeshore 0 Temp #04 at end (deg K)
# SELS005T=              43.9996 / SPIRou Lakeshore 0 Temp #05 at end (deg K)
# SELS006T=              44.0022 / SPIRou Lakeshore 0 Temp #06 at end (deg K)
# SELS007T=              55.7091 / SPIRou Lakeshore 0 Temp #07 at end (deg K)
# SELS008T=             119.0630 / SPIRou Lakeshore 0 Temp #08 at end (deg K)
# SELS009T=              76.9973 / SPIRou Lakeshore 0 Temp #09 at end (deg K)
# SELS010T=              83.5057 / SPIRou Lakeshore 0 Temp #10 at end (deg K)
# SELS011T=              85.9900 / SPIRou Lakeshore 0 Temp #11 at end (deg K)
# SELS100T=              74.4043 / SPIRou Lakeshore 1 Temp #00 at end (deg K)
# SELS101T=              74.4260 / SPIRou Lakeshore 1 Temp #01 at end (deg K)
# SELS102T=              74.5072 / SPIRou Lakeshore 1 Temp #02 at end (deg K)
# SELS103T=              74.6949 / SPIRou Lakeshore 1 Temp #03 at end (deg K)
# SELS104T=              74.4711 / SPIRou Lakeshore 1 Temp #04 at end (deg K)
# SELS105T=              80.9726 / SPIRou Lakeshore 1 Temp #05 at end (deg K)
# SELS106T=              74.3813 / SPIRou Lakeshore 1 Temp #06 at end (deg K)
# SELS107T=              74.4601 / SPIRou Lakeshore 1 Temp #07 at end (deg K)
# SELS108T=             273.8200 / SPIRou Lakeshore 1 Temp #08 at end (deg K)
# SELS109T=              90.0000 / SPIRou Lakeshore 1 Temp #09 at end (deg K)
# SELS110T=              79.9904 / SPIRou Lakeshore 1 Temp #10 at end (deg K)
# SELS111T=              85.6250 / SPIRou Lakeshore 1 Temp #11 at end (deg K)
# SEL00I_T=              73.5001 / SPIRou Loop #0 Temp at end (deg K)
# SEL00H_V=               27.710 / SPIRou Loop #0 Heater Output at end (%)
# SEL01I_T=              73.5002 / SPIRou Loop #1 Temp at end (deg K)
# SEL01H_V=               28.144 / SPIRou Loop #1 Heater Output at end (%)
# SEL02I_T=              73.5001 / SPIRou Loop #2 Temp at end (deg K)
# SEL02H_V=               26.560 / SPIRou Loop #2 Heater Output at end (%)
# SEL03I_T=              76.9973 / SPIRou Loop #3 Temp at end (deg K)
# SEL03H_V=                8.564 / SPIRou Loop #3 Heater Output at end (%)
# SEL04I_T=              84.0246 / SPIRou Loop #4 Temp at end (deg K)
# SEL04H_V=               12.883 / SPIRou Loop #4 Heater Output at end (%)
# SEL05I_T=              77.5587 / SPIRou Loop #5 Temp at end (deg K)
# SEL05H_V=               15.462 / SPIRou Loop #5 Heater Output at end (%)
# SEL06I_T=              78.9028 / SPIRou Loop #6 Temp at end (deg K)
# SEL06H_V=               15.147 / SPIRou Loop #6 Heater Output at end (%)
# SEL07I_T=              77.9445 / SPIRou Loop #7 Temp at end (deg K)
# SEL07H_V=               12.231 / SPIRou Loop #7 Heater Output at end (%)
# SEL08I_T=              79.9937 / SPIRou Loop #8 Temp at end (deg K)
# SEL08H_V=                1.115 / SPIRou Loop #8 Heater Output at end (%)
# SEL09I_T=              89.9995 / SPIRou Loop #9 Temp at end (deg K)
# SEL09H_V=                5.668 / SPIRou Loop #9 Heater Output at end (%)
# SEL10I_T=              43.9996 / SPIRou Loop #10 Temp at end (deg K)
# SEL10H_V=               44.836 / SPIRou Loop #10 Heater Output at end (%)
# SEL11I_T=              44.0022 / SPIRou Loop #11 Temp at end (deg K)
# SEL11H_V=               15.578 / SPIRou Loop #11 Heater Output at end (%)
# SEL12I_T=              85.9900 / SPIRou Loop #12 Temp at end (deg K)
# SEL12H_V=                4.794 / SPIRou Loop #12 Heater Output at end (%)
# SEL13I_T=              83.5057 / SPIRou Loop #13 Temp at end (deg K)
# SEL13H_V=                0.000 / SPIRou Loop #13 Heater Output at end (%)
# OBJRV   =               -54.00 / Object radial velocity kms
# REQRVP  =                 1.00 / Requested radial velocity precision meters per
# SGISUST = 'OFF     '           / SPIRou Guider ISU State
# SGGDST  = 'TCS     '           / SPIRou Guider Raster State (OFF, ON, TCS)
# SGFRMRT =                 4.76 / SPIRou Guider Frame Rate (Hz)
# SGETIME =             200.0000 / SPIRou Guider Exposure Time (ms)
# SGNULLX =               350.09 / SPIRou Guider Null Position X location (pixel)
# SGNULLY =               267.58 / SPIRou Guider Null Position Y location (pixel)
# SGWINX0 =                  333 / SPIRou Guider X0 Hole Subraster coordinate
# SGWINY0 =                  250 / SPIRou Guider Y0 Hole Subraster coordinate
# SGWINX1 =                  364 / SPIRou Guider X1 Hole Subraster coordinate
# SGWINY1 =                  281 / SPIRou Guider Y1 Hole Subraster coordinate
# SGOFFX0 =                -9999 / SPIRou Guider X0 Offset Star Subraster coord
# SGOFFY0 =                -9999 / SPIRou Guider Y0 Offset Star Subraster coord
# SGOFFX1 =                -9999 / SPIRou Guider X1 Offset Star Subraster coord
# SGOFFY1 =                -9999 / SPIRou Guider Y1 Offset Star Subraster coord
# SGHOLEX =               350.09 / SPIRou Guider Hole Position X location (pixel)
# SGHOLEY =               267.58 / SPIRou Guider Hole Position Y location (pixel)
# SGCHOLEX=             349.9212 / SPIRou Guider Calculated Hole X loc (pixel)
# SGCHOLEY=             267.8995 / SPIRou Guider Calculated Hole Y loc (pixel)
# SGEHOLEX=               0.0529 / SPIRou Guider Calculated Hole X error (pixel)
# SGEHOLEY=               0.0499 / SPIRou Guider Calculated Hole Y error (pixel)
# SGCSTARX=             350.1206 / SPIRou Guider Calculated Star X loc (pixel)
# SGCSTARY=             267.9179 / SPIRou Guider Calculated Star Y loc (pixel)
# SGESTARX=               0.0260 / SPIRou Guider Calculated Star X error (pixel)
# SGESTARY=               0.0265 / SPIRou Guider Calculated Star Y error (pixel)
# SGCNOFFX=               0.0306 / SPIRou Guider Calculated Null X offset (pixel
# SGCNOFFY=               0.3379 / SPIRou Guider Calculated Null Y offset (pixel)
# SGCSEE  =               0.6147 / SPIRou Guider Calculated Seeing
# SGESEE  =               0.0046 / SPIRou Guider Calculated Seeing Error
# SGCMAGN =              10.8146 / SPIRou Guider Calculated Magnitude
# SGEMAGN =               0.0407 / SPIRou Guider Calculated Magnitude Error
# SGSSEE  =                 0.59 / SPIRou Guider Seeing Last Sequence Measurement
# SPEMSNR =                42.90 / SPIRou Exposure Meter SNR Estimate
# SPEMSNRC=                14.50 / SPIRou Exposure Meter C Fiber SNR Estimate
# DOMESHUT= 'OPEN    '           / Dome shutter state (OPEN/CLOSED)
# MIRRCOV = 'OPEN    '           / Mirror cover state (OPEN/CLOSED)
# WINDSCR =                    0 / Windscreen elevation in degrees
# DOMELOUV= 'CLOSED  '           / Dome louver state (OPEN/CLOSED)
# VENTMODE= 'MANUAL  '           / Dome venting control mode
# VENTL1  = 'UNKNOWN:-9999:-9999:-9999' / Dome vent L1 door and vane configuration
# VENTL2  = 'UNKNOWN:-9999:-9999:-9999' / Dome vent L2 door and vane configuration
# VENTL3  = '2/3 OPEN:70:70:70'  / Dome vent L3 door and vane configuration
# VENTL4  = '2/3 OPEN:70:70:70'  / Dome vent L4 door and vane configuration
# VENTL5  = '2/3 OPEN:70:70:70'  / Dome vent L5 door and vane configuration
# VENTL6  = '2/3 OPEN:70:70:70'  / Dome vent L6 door and vane configuration
# VENTR1  = 'UNKNOWN:-9999:-9999:-9999' / Dome vent R1 door and vane configuration
# VENTR2  = 'UNKNOWN:-9999:-9999:-9999' / Dome vent R2 door and vane configuration
# VENTR3  = '2/3 OPEN:70:70:70'  / Dome vent R3 door and vane configuration
# VENTR4  = '2/3 OPEN:70:70:70'  / Dome vent R4 door and vane configuration
# VENTR5  = '2/3 OPEN:70:70:70'  / Dome vent R5 door and vane configuration
# VENTR6  = '2/3 OPEN:70:70:70'  / Dome vent R6 door and vane configuration
# TESPMIRE=                -0.90 / 03 temp, surface, primary mirror east deg C
# TESPMIRW=                 3.40 / 02 temp, surface, primary mirror west deg C
# TESPMIRS=                 3.61 / 01 temp, surface, primary mirror west side degC
# TEAPMCLW=                 2.80 / 54 temp, air, primary mirror cell west deg C
# TEAMIRCI=               851.29 / 58 temp, air, mirror cooling in at unit deg C
# TEAMIRCO=                 2.60 / 27 temp, air, mirror cooling out at cell deg C
# TEAPMSPN=             -9999.90 / 65 temp, air, mirror spigot north cass deg C
# TEAPMSPS=                 5.36 / 64 temp, air, mirror spigot nouth M3 deg C
# TEATRNGE=                 2.90 / 23 temp, air, top ring east deg C
# TEATRNGW=                 2.48 / 06 temp, air, top ring west deg C
# TEANRLSB=                11.56 / 19 temp, air, north rail support beam deg C
# TESHRSET=                15.79 / 08 temp, surface, horseshoe east top deg C
# TESTTRSH=                 3.40 / 97 temp, surface, telescope truss S high deg C
# TESTTRNM=                 2.88 / 94 temp, surface, telescope truss N mid deg C
# TESTTREM=                 6.07 / 95 temp, surface, telescope truss E mid deg C
# TESTTRWM=                 3.26 / 96 temp, surface, telescope truss W mid deg C
# TESTTRSL=                 3.37 / 98 temp, surface, telescope truss S low deg C
# TESTTRSE=                 3.13 / 69 temp, surface, telescope truss SE lower degC
# TEALOWWS=                -1.50 / 38 temp, air, dome lower weather stat side degC
# TEATOPWS=                -1.40 / 36 temp, air, dome top weather stat side deg C
# TEATOPOP=               849.80 / 37 temp, air, dome top opposite weath side degC
# TEA2INCH=                 2.89 / 45 temp, air, two inches above fifth floor degC
# TEA2INEB=                 3.10 / 53 temp, air, two inches up by electronics degC
# TEA6FOOT=                 2.33 / 43 temp, air, six feet above fifth floor deg C
# TESCONRM=                 4.65 / 61 temp, surface, floor above control room degC
# TESPIERN=                 5.50 / 59 temp, surface, floor by north pier deg C
# TESPIERS=                 4.10 / 60 temp, surface, floor by south pier deg C
# TEAWTHRT=                 2.80 / 35 temp, air, weathertron deg C
# TEMPERAT=                 2.02 / 86 temp, air, weather tower deg C
# WINDSPED=                10.13 / 84 wind speed, weather tower knots
# WINDDIR =               234.41 / 85 wind direction, weather tower deg (N=0 E=90)
# RELHUMID=                40.05 / 87 relative humidity, weather tower %
# PRESSURE=               620.08 / 31 barometric pressure, control room mb
# DDSEEMEN=             -9999.90 / Dome DIMM mean seeing, arc seconds
# DDSEEMED=             -9999.90 / Dome DIMM median seeing, arc seconds
# DDSEEMOD=             -9999.90 / Dome DIMM mode seeing, arc seconds
# DDSEESTD=             -9999.90 / Dome DIMM seeing deviation, arc seconds
# WMSEEMEN=                 0.37 / Weather tower MASS mean seeing, arc seconds
# WMSEEMED=                 0.38 / Weather tower MASS median seeing, arc seconds
# WMSEEMOD=                 0.37 / Weather tower MASS mode seeing, arc seconds
# WMSEESTD=                 0.05 / Weather tower MASS seeing deviation, arc second
# WDSEEMEN=                 0.44 / Weather tower DIMM mean seeing, arc seconds
# WDSEEMED=                 0.44 / Weather tower DIMM median seeing, arc seconds
# WDSEEMOD=                 0.44 / Weather tower DIMM mode seeing, arc seconds
# WDSEESTD=                 0.02 / Weather tower DIMM seeing deviation, arc second
# SPOZPMEN=                 0.08 / SkyProbe (orig) mean absorption, magnitude
# SPOZPMED=                 0.09 / SkyProbe (orig) median absorption, magnitude
# SPOZPMOD=                 0.08 / SkyProbe (orig) mode absorption, magnitude
# SPOZPSTD=                 0.01 / SkyProbe (orig) absorption deviation, magnitude
# QRUNID  = '21BQ11  '           / Q RunID
# QOBSERVE= 'Callie Crowder'     / Name of Q Observer
# QCOORD  = 'Helen Januszewski'  / Name of Q Coordinator
# REL_DATE= '2023-02-28T00:00:00' / UTC Release Date
# MET_DATE= '2021-10-27T05:40:37' / UTC Release Date
# QTOKEN  = 'f59d7d13-965d-4cab-b155-f1946d439ab2' / Queue Token
# OBTOKEN = '21BF16-1631142487698-1' / Observing Block Token
# EXPTOKEN= '21BF16-WH64F4PEP1'  / Exposure Token
# OCTOKEN = '21BF16-PKF2C4E0A0'  / Observing Component Token
# TRGTOKEN= '21BF16-1592881942918' / Target Token
# OCEXPNUM=                    1 / The Exposure Index for the OC
# TRG_TYPE= 'TARGET  '           / target or sky object
# SNRGOAL =                36.00 / Goal SNR per pixel per frame
# OBJTEMP =              2511.00 / Target effective temperature
# GAIAID  =  2635476908753563008 / Gaia catalog target identifier
# GAIADR  = 'Gaia DR2'           / Gaia catalog data release
# CRUNID  = '21Bp03  '           / Elixir camera run ID
# DRSOBJN = 'TRAPPIST1'          / APERO-cleaned Target name
# MJDMID  =    59514.24942306643 / APERO calculated Mid Observation time [mjd]
# MJDMIDMD= 'header  '           / Mid Observation time calc method
# DRSMODE = 'SPECTROSCOPY'       / APERO-mode (Spectroscopy or Polar)
# DPRTYPE = 'OBJ_DARK'           / APERO-type of file (from pre-process)
# PP_OBJN = 'TRAPPIST1'          / cleaned object name to be used by the DRS
# PP_OBJNS= 'Trappist-1'         / Original object name as in header
# PP_RA   =          346.6265216 / The RA [in deg] used by the DRS
# PP_RAS  = 'Gaia EDR3'          / Source of the ra used by the DRS
# PP_DEC  =         -5.043528319 / The dec [in deg] used by the DRS
# PP_DECS = 'Gaia EDR3'          / Source of the dec used by the DRS
# PP_EPOCH=            2457388.5 / The Epoch used by the DRS
# PP_PMRA =          930.7875226 / The pmra [mas/yr] used by the DRS
# PP_PMRAS= 'Gaia EDR3'          / Source of the pmra used by the DRS
# PP_PMDE =          -479.037541 / The pmdec [mas/yr] used by the DRS
# PP_PMDES= 'Gaia EDR3'          / Source of the pmde used by the DRS
# PP_PLX  =          80.21231613 / The parallax [mas] used by the DRS
# PP_PLXS = 'Gaia EDR3'          / Source of the plx used by the DRS
# PP_RV   =             -54000.0 / The RV [m/s] used by the DRS
# PP_RVS  = '2015ApJS..220...18B' / Source of the rv used by the DRS
# PP_TEFF =               2400.0 / The Teff [K] used by the DRS
# PP_TEFFS= '2018A&A...620A.180R' / Source of the Teff used by the DRS
# PP_SPT  = 'M7.5e   '           / The SpT used by the DRS
# PP_SPTS = '2000AJ....120.1085G' / Source of the SpT used by the DRS
# PP_SRCE = 'database'           / The source of DRS object data
# PP_DDATE= '2023-10-18 16:14:49.504' / The date of source of DRS object data
# PVERSION= '0.7.288 '           / APERO Pre-Processing version
# DRSVDATE= '2023-09-06'         / DRS Release date
# DRSPDATE= '2023-10-25 06:47:42.161' / DRS Processed date
# DETOFFDX=                    0 / Pixel offset in x from readout lag
# DETOFFDY=                    0 / Pixel offset in y from readout lag
# NBADINTE=                41697 / No. bad px intercept cosmic reject
# NBADSLOP=                 3147 / No. bad px slope cosmic reject
# NBADBOTH=                 1025 / No. bad px both cosmic reject
# VERSION = '0.7.288 '           / APERO version
# DRSPID  = 'PID-00016982164621608620-UOKK' / The process ID that outputted this f
# DRSOUTID= 'EXT_E2DS_FF'        / DRS output identification code
# FIBER   = 'AB      '           / The fiber name
# INF1000 = '2665330o_pp.fits'   / Input file used to create output file=0
# CDBDARK = '2901090d_pp_dark_ref.fits' / The cal DARK file for extract
# CDTDARK =    60223.70232645208 / MJDMID of cal DARK file used
# CDBBAD  = '0B9769CFC9_pp_badpixel.fits' / The cal BADPIX file for extract
# CDTBAD  =    59514.39284942672 / MJDMID of cal BADPIX file used
# CDBBACK = '0B9769CFC9_pp_bmap.fits' / The cal BKGRDMAP file for extract
# CDTBACK =    59514.39284942672 / MJDMID of cal BKGRDMAP file used
# CAL_FLIP= 'ALL     '           / Whether the image was flipped from pp
# CAL_TOE =                    1 / Whether the flux was converted to e-
# CAL_SIZE=                    1 / Whether the image was resized from pp
# CDBORDP = '9B98D8743C_pp_shapel_orderps_AB.fits' / The cal ORDER_PROFILE file us
# CDTORDP =    59514.38810172671 / MJDMID of cal ORDER_PROFILE file used
# CDBLOCO = '2B3AD552BC_pp_loco_AB.fits' / The cal LOC file used
# CDTLOCO =    59514.38810172671 / MJDMID of cal LOC file used
# CDBSHAPL= '9B98D8743C_pp_shapel.fits' / The cal SHAPEL file used
# CDTSHAPL=    59514.40700876403 / MJDMID of cal SHAPEL file used
# CDBSHAPX= '3444961B5D_pp_shapex.fits' / The cal SHAPE DX file used
# CDTSHAPX=    59092.40154091403 / MJDMID of cal SHAPE DX file used
# CDBSHAPY= '3444961B5D_pp_shapey.fits' / The cal SHAPE DX file used
# CDTSHAPY=    59092.40154091403 / MJDMID of cal SHAPE DX file used
# CDBFLAT = '4633781D93_pp_flat_AB.fits' / The cal FLAT file used
# CDTFLAT =    59514.38812741005 / MJDMID of cal FLAT file used
# CDBBLAZE= '4633781D93_pp_blaze_AB.fits' / The cal BLAZE file used
# CDTBLAZE=    59514.38812741005 / MJDMID of cal BLAZE file used
# CDBTHERM= '8FCAE28BFC_pp_thermal_e2ds_tel_AB.fits' / The cal THERMAL file used
# CDTTHERM=    59514.37378852708 / MJDMID of cal THERMAL file used
# THRM_RAT=     1.23946412830215 / Ratio 1 used for thermal correction
# THRM_RU = 'tapas   '           / Ratio method used for thermal correction
# CDBWAVE = '9B98D8743C_pp_e2dsff_AB_wave_night_AB.fits' / The cal WAVE file used
# CDTWAVE =    59514.40700876403 / MJDMID of cal WAVE file used
# CDBLEAKM= 'No leak '           / The cal LEAKM file used
# CDTLEAKM= 'No leak '           / MJDMID of cal LEAK file used
# CDBLEAKR= 'No leak '           / The cal ref LEAKM file used
# CDTLEAKR= 'No leak '           / MJDMID of cal ref LEAK file used
# CAL_FTYP= 'OBJ     '           / What this fiber was identified as
# QCC001N = 'image   '           / Quality control parameter name
# QCC001V = 'NaN     '           / Quality control measured value
# QCC001L = 'image is all NaN'   / Quality control logic used
# QCC001P =                    1 / Quality control param passed QC
# QCC_ALL =                    T
# SHAPE_DX=  0.24212865879778958 / Shape transform dx parameter
# SHAPE_DY=  0.06026640417286908 / Shape transform dy parameter
# SHAPE_A =   1.0000102019425003 / Shape transform A parameter
# SHAPE_B = 5.43700446571734E-06 / Shape transform B parameter
# SHAPE_C = -2.0181207796820E-05 / Shape transform C parameter
# SHAPE_D =   1.0000020925352815 / Shape transform D parameter
# EXT_TYPE= 'EXT_E2DS_FF'        / Extract type (E2DS or E2DSFF)
# EFFRON  =    8.793388796434856 / Measured eff readout noise before ext
# EXTSN000=   3.5010924535589227 / Extract: S_N order center order=0
# EXTSN001=    4.440381689789136 / Extract: S_N order center order=1
# EXTSN002=    5.334821723220013 / Extract: S_N order center order=2
# EXTSN003=    8.066479915527388 / Extract: S_N order center order=3
# EXTSN004=    9.109889459790622 / Extract: S_N order center order=4
# EXTSN005=   11.790567932635845 / Extract: S_N order center order=5
# EXTSN006=   10.745655824793337 / Extract: S_N order center order=6
# EXTSN007=   10.621055688668406 / Extract: S_N order center order=7
# EXTSN008=   12.508289226195537 / Extract: S_N order center order=8
# EXTSN009=   16.425016365112775 / Extract: S_N order center order=9
# EXTSN010=   13.609719376362104 / Extract: S_N order center order=10
# ...
# WAVE0190= -0.00011525322747804 / Wavelength coefficients order=31 coeffs=4
# WAVE0191=  4.4752779528175E-05 / Wavelength coefficients order=31 coeffs=5
# WAVE0192=   1634.3786492262402 / Wavelength coefficients order=32 coeffs=0
# WAVE0193=   25.381103144115915 / Wavelength coefficients order=32 coeffs=1
# WAVE0194=  -0.7764708386934499 / Wavelength coefficients order=32 coeffs=2
# WAVE0195= 0.000616088912730393 / Wavelength coefficients order=32 coeffs=3
# WAVE0196= -7.2153225936866E-05 / Wavelength coefficients order=32 coeffs=4
# WAVE0197=  6.6483125969425E-05 / Wavelength coefficients order=32 coeffs=5
# WAVE0198=   1669.9401946609796 / Wavelength coefficients order=33 coeffs=0
# WAVE0199=    25.92887056140363 / Wavelength coefficients order=33 coeffs=1
# WAVE0200=  -0.7932262819613218 / Wavelength coefficients order=33 coeffs=2
# WAVE0201= 0.000627099160961371 / Wavelength coefficients order=33 coeffs=3
# WAVE0202= -9.4693365917038E-05 / Wavelength coefficients order=33 coeffs=4
# WAVE0203= 3.40280146214506E-05 / Wavelength coefficients order=33 coeffs=5
# WAVE0204=   1707.0819439068998 / Wavelength coefficients order=34 coeffs=0
# WAVE0205=   26.501227662621307 / Wavelength coefficients order=34 coeffs=1
# WAVE0206=  -0.8106417707606514 / Wavelength coefficients order=34 coeffs=2
# WAVE0207= 0.000618612586436064 / Wavelength coefficients order=34 coeffs=3
# WAVE0208= -8.8281861341192E-05 / Wavelength coefficients order=34 coeffs=4
# WAVE0209= 4.20398240574463E-05 / Wavelength coefficients order=34 coeffs=5
# WAVE0210=   1745.9113722285051 / Wavelength coefficients order=35 coeffs=0
# WAVE0211=    27.09947016273808 / Wavelength coefficients order=35 coeffs=1
# WAVE0212=  -0.8288219092911352 / Wavelength coefficients order=35 coeffs=2
# WAVE0213= 0.000647349685128093 / Wavelength coefficients order=35 coeffs=3
# WAVE0214= -0.00010712203900022 / Wavelength coefficients order=35 coeffs=4
# WAVE0215= 5.68891306836789E-05 / Wavelength coefficients order=35 coeffs=5
# WAVE0216=   1786.5463473936056 / Wavelength coefficients order=36 coeffs=0
# WAVE0217=    27.72551181463295 / Wavelength coefficients order=36 coeffs=1
# WAVE0218=  -0.8478462228470198 / Wavelength coefficients order=36 coeffs=2
# WAVE0219= 0.000646139687032189 / Wavelength coefficients order=36 coeffs=3
# WAVE0220= -9.9698312446733E-05 / Wavelength coefficients order=36 coeffs=4
# WAVE0221= 7.10765180707786E-05 / Wavelength coefficients order=36 coeffs=5
# WAVE0222=    1829.115813151122 / Wavelength coefficients order=37 coeffs=0
# WAVE0223=   28.381056770664483 / Wavelength coefficients order=37 coeffs=1
# WAVE0224=  -0.8677583962589599 / Wavelength coefficients order=37 coeffs=2
# WAVE0225= 0.000651068770440607 / Wavelength coefficients order=37 coeffs=3
# WAVE0226= -6.5801645496284E-05 / Wavelength coefficients order=37 coeffs=4
# WAVE0227= 5.82160533530352E-05 / Wavelength coefficients order=37 coeffs=5
# WAVE0228=   1873.7612826883228 / Wavelength coefficients order=38 coeffs=0
# WAVE0229=   29.068283517243408 / Wavelength coefficients order=38 coeffs=1
# WAVE0230=  -0.8887263135902995 / Wavelength coefficients order=38 coeffs=2
# WAVE0231= 0.000630195851917876 / Wavelength coefficients order=38 coeffs=3
# WAVE0232= -7.7741897748761E-05 / Wavelength coefficients order=38 coeffs=4
# WAVE0233= 3.68769365975786E-05 / Wavelength coefficients order=38 coeffs=5
# WAVE0234=    1920.638617938626 / Wavelength coefficients order=39 coeffs=0
# WAVE0235=    29.78995355882743 / Wavelength coefficients order=39 coeffs=1
# WAVE0236=  -0.9108303828010027 / Wavelength coefficients order=39 coeffs=2
# WAVE0237=   0.0006558882891362 / Wavelength coefficients order=39 coeffs=3
# WAVE0238= -9.3743183192111E-05 / Wavelength coefficients order=39 coeffs=4
# WAVE0239= 1.45148205999982E-05 / Wavelength coefficients order=39 coeffs=5
# WAVE0240=   1969.9197634215548 / Wavelength coefficients order=40 coeffs=0
# WAVE0241=   30.548479138522072 / Wavelength coefficients order=40 coeffs=1
# WAVE0242=  -0.9337258025080963 / Wavelength coefficients order=40 coeffs=2
# WAVE0243= 0.000561522363330886 / Wavelength coefficients order=40 coeffs=3
# WAVE0244= -0.00013537386407409 / Wavelength coefficients order=40 coeffs=4
# WAVE0245=  6.5555091267509E-05 / Wavelength coefficients order=40 coeffs=5
# WAVE0246=   2021.7941830802856 / Wavelength coefficients order=41 coeffs=0
# WAVE0247=   31.346713494285595 / Wavelength coefficients order=41 coeffs=1
# WAVE0248=  -0.9582451773955708 / Wavelength coefficients order=41 coeffs=2
# WAVE0249= 0.000657745315410606 / Wavelength coefficients order=41 coeffs=3
# WAVE0250= -8.7057681397983E-05 / Wavelength coefficients order=41 coeffs=4
# WAVE0251= 4.59682751123544E-05 / Wavelength coefficients order=41 coeffs=5
# WAVE0252=    2076.472442509829 / Wavelength coefficients order=42 coeffs=0
# WAVE0253=   32.187521965032694 / Wavelength coefficients order=42 coeffs=1
# WAVE0254=  -0.9840518757004513 / Wavelength coefficients order=42 coeffs=2
# WAVE0255= 0.000537523144210667 / Wavelength coefficients order=42 coeffs=3
# WAVE0256= -0.00012056352341948 / Wavelength coefficients order=42 coeffs=4
# WAVE0257= 8.25903964580838E-05 / Wavelength coefficients order=42 coeffs=5
# WAVE0258=    2134.188015998494 / Wavelength coefficients order=43 coeffs=0
# WAVE0259=   33.074777057928536 / Wavelength coefficients order=43 coeffs=1
# WAVE0260=   -1.011024267558196 / Wavelength coefficients order=43 coeffs=2
# WAVE0261= 0.000590964679646621 / Wavelength coefficients order=43 coeffs=3
# WAVE0262= -9.6563075398815E-05 / Wavelength coefficients order=43 coeffs=4
# WAVE0263= 5.74326032640769E-05 / Wavelength coefficients order=43 coeffs=5
# WAVE0264=   2195.2007280275043 / Wavelength coefficients order=44 coeffs=0
# WAVE0265=    34.01237769628552 / Wavelength coefficients order=44 coeffs=1
# WAVE0266=   -1.039596984545224 / Wavelength coefficients order=44 coeffs=2
# WAVE0267= 0.000569324815767206 / Wavelength coefficients order=44 coeffs=3
# WAVE0268= -0.00014047903632854 / Wavelength coefficients order=44 coeffs=4
# WAVE0269= 7.09840499758393E-05 / Wavelength coefficients order=44 coeffs=5
# WAVE0270=   2259.8013009281412 / Wavelength coefficients order=45 coeffs=0
# WAVE0271=    35.00457327021354 / Wavelength coefficients order=45 coeffs=1
# WAVE0272=  -1.0701992440732695 / Wavelength coefficients order=45 coeffs=2
# WAVE0273= 0.000540978721482579 / Wavelength coefficients order=45 coeffs=3
# WAVE0274= -5.7420046748742E-05 / Wavelength coefficients order=45 coeffs=4
# WAVE0275= 0.000115068057975516 / Wavelength coefficients order=45 coeffs=5
# WAVE0276=   2328.3154950351754 / Wavelength coefficients order=46 coeffs=0
# WAVE0277=    36.05655181653512 / Wavelength coefficients order=46 coeffs=1
# WAVE0278=  -1.1020575357633915 / Wavelength coefficients order=46 coeffs=2
# WAVE0279= 0.000464732205180894 / Wavelength coefficients order=46 coeffs=3
# WAVE0280= -0.00014906226271138 / Wavelength coefficients order=46 coeffs=4
# WAVE0281=  0.00010552633222467 / Wavelength coefficients order=46 coeffs=5
# WAVE0282=   2401.1101355671276 / Wavelength coefficients order=47 coeffs=0
# WAVE0283=    37.17291775418689 / Wavelength coefficients order=47 coeffs=1
# WAVE0284=  -1.1361806461480293 / Wavelength coefficients order=47 coeffs=2
# WAVE0285= 0.000468858520399578 / Wavelength coefficients order=47 coeffs=3
# WAVE0286=  -0.0001087220198035 / Wavelength coefficients order=47 coeffs=4
# WAVE0287= 8.49168391144793E-05 / Wavelength coefficients order=47 coeffs=5
# WAVE0288=   2478.5948369407824 / Wavelength coefficients order=48 coeffs=0
# WAVE0289=     38.3553790452162 / Wavelength coefficients order=48 coeffs=1
# WAVE0290=  -1.1745102142213046 / Wavelength coefficients order=48 coeffs=2
# WAVE0291= -0.00035249253275941 / Wavelength coefficients order=48 coeffs=3
# WAVE0292= -0.00059145172185565 / Wavelength coefficients order=48 coeffs=4
# WAVE0293= -0.00011140648378818 / Wavelength coefficients order=48 coeffs=5
# WAVEEC00=                   79 / Echelle order numbers order=0
# WAVEEC01=                   78 / Echelle order numbers order=1
# WAVEEC02=                   77 / Echelle order numbers order=2
# WAVEEC03=                   76 / Echelle order numbers order=3
# WAVEEC04=                   75 / Echelle order numbers order=4
# WAVEEC05=                   74 / Echelle order numbers order=5
# WAVEEC06=                   73 / Echelle order numbers order=6
# WAVEEC07=                   72 / Echelle order numbers order=7
# WAVEEC08=                   71 / Echelle order numbers order=8
# WAVEEC09=                   70 / Echelle order numbers order=9
# WAVEEC10=                   69 / Echelle order numbers order=10
# WAVEEC11=                   68 / Echelle order numbers order=11
# WAVEEC12=                   67 / Echelle order numbers order=12
# WAVEEC13=                   66 / Echelle order numbers order=13
# WAVEEC14=                   65 / Echelle order numbers order=14
# WAVEEC15=                   64 / Echelle order numbers order=15
# WAVEEC16=                   63 / Echelle order numbers order=16
# WAVEEC17=                   62 / Echelle order numbers order=17
# WAVEEC18=                   61 / Echelle order numbers order=18
# WAVEEC19=                   60 / Echelle order numbers order=19
# WAVEEC20=                   59 / Echelle order numbers order=20
# WAVEEC21=                   58 / Echelle order numbers order=21
# WAVEEC22=                   57 / Echelle order numbers order=22
# WAVEEC23=                   56 / Echelle order numbers order=23
# WAVEEC24=                   55 / Echelle order numbers order=24
# WAVEEC25=                   54 / Echelle order numbers order=25
# WAVEEC26=                   53 / Echelle order numbers order=26
# WAVEEC27=                   52 / Echelle order numbers order=27
# WAVEEC28=                   51 / Echelle order numbers order=28
# WAVEEC29=                   50 / Echelle order numbers order=29
# WAVEEC30=                   49 / Echelle order numbers order=30
# WAVEEC31=                   48 / Echelle order numbers order=31
# WAVEEC32=                   47 / Echelle order numbers order=32
# WAVEEC33=                   46 / Echelle order numbers order=33
# WAVEEC34=                   45 / Echelle order numbers order=34
# WAVEEC35=                   44 / Echelle order numbers order=35
# WAVEEC36=                   43 / Echelle order numbers order=36
# WAVEEC37=                   42 / Echelle order numbers order=37
# WAVEEC38=                   41 / Echelle order numbers order=38
# WAVEEC39=                   40 / Echelle order numbers order=39
# WAVEEC40=                   39 / Echelle order numbers order=40
# WAVEEC41=                   38 / Echelle order numbers order=41
# WAVEEC42=                   37 / Echelle order numbers order=42
# WAVEEC43=                   36 / Echelle order numbers order=43
# WAVEEC44=                   35 / Echelle order numbers order=44
# WAVEEC45=                   34 / Echelle order numbers order=45
# WAVEEC46=                   33 / Echelle order numbers order=46
# WAVEEC47=                   32 / Echelle order numbers order=47
# WAVEEC48=                   31 / Echelle order numbers order=48
# WFP_FILE= '9B98D8743C_pp_e2dsff_AB_wave_night_AB.fits' / WFP source file
# WFPDRIFT= 0.018367997955739807 / Wavelength sol absolute CCF FP Drift [km/s]
# WFPFWHM =    5.652521572073261 / FWHM of wave sol FP CCF [km/s]
# WFPCONT =    94.44930307564333 / wave sol FP Contrast of CCF (%)
# WFPMASK = 'smart_fp_mask.mas'  / wave sol FP Mask filename
# WFPLINE =              19813.0 / wave sol FP nbr of lines used
# WFPTRV  =                  0.0 / wave sol FP target RV [km/s]
# WFPWIDTH=                  7.5 / wave sol FP CCF width [km/s]
# WFPSTEP =                  0.5 / wave sol FP CCF step [km/s]
# WCAV000 =   1123.0696483813226 / Wave cavity polynomial coeffs=0
# WCAV001 =  -334.39423153428504 / Wave cavity polynomial coeffs=1
# WCAV002 =   -734.4550362480005 / Wave cavity polynomial coeffs=2
# WCAV003 =   174.48683550078394 / Wave cavity polynomial coeffs=3
# WCAV004 =    81.19836872697287 / Wave cavity polynomial coeffs=4
# WCAV005 =    -45.4243723162354 / Wave cavity polynomial coeffs=5
# WCAV006 =   -7.488945831266736 / Wave cavity polynomial coeffs=6
# WCAV007 =    7.043105551697514 / Wave cavity polynomial coeffs=7
# WCAV008 =  -2.5744821224879613 / Wave cavity polynomial coeffs=8
# WCAV009 =   -7.587744417696292 / Wave cavity polynomial coeffs=9
# WCAV_DEG=                    9 / Wave cavity fit degree
# WCAV_PED=           24498000.0 / Wave cavity pedestal
# WAVEMHC = 0.000295472100239756 / Wave mean hc velocity
# WAVEEMHC=  0.45147139666985275 / Wave error mean hc velocity
# WAVEPOLY= 'Chebyshev'          / type of wave polynomial
# BC_LONG =          -155.468876 / OBS Longitude [deg] used to calc. BERV
# BC_LAT  =            19.825252 / OBS Latitude [deg] used to calc. BERV
# BC_ALT  =               4204.0 / OBS Altitude [m] used to calc. BERV
# BERV    =  -22.443060793229094 / Barycentric Velocity calc. in BERVSRCE [km/s]
# BJD     =   2459514.7540123938 / Barycentric Julian date mid exp calc. BERVSRCE
# BERVMAX =   30.467185216302173 / Max BERV 1 yr calc. in BERVSRCE [km/s]
# DBERV   = 3.44978364594794E-05 / Deviation in BERV in BERVSRCE [km/s/s]
# BERVSRCE= 'barycorrpy'         / How BERV was calculated
# BERV_EST= 'NaN     '           / Barycentric Velocity estimate [km/s]
# BJD_EST = 'NaN     '           / Barycentric Julian date estimate
# BERVMAXE= 'NaN     '           / Max BERV 1 yr estimate [km/s]
# DBERVE  = 'NaN     '           / Deviation in BERV estimate [km/s/s]
# BERVOBST=   2459514.7494230666 / BERV observation time used [days]
# BERVOBSM= 'header[MJDMID]'     / BERV method used to calc observation time
# LEAKCORR=                    0 / Whether DARK_FP leakage correction has been don
# LEAK_BPU= 'No leak '           / LEAK bckgrd percentile used for leakage corr
# LEAK_NPU= 'No leak '           / LEAK norm percentile used for leakage corr
# LEAK_LPU= 'No leak '           / LEAK lower bound percentile used for leakage co
# LEAK_UPU= 'No leak '           / LEAK upper bound percentile used for leakage co
# LEAKBADR= 'No leak '           / LEAK bad ratio offset limit used for leakage co
