# %%
import os
from astropy.io import fits

fits_file = '/home/mathisb/Github/HRS_data/SPIRou/WASP-33b/2022-01-16/68B99F66A2_pp_e2dsff_AB_wave_night_AB.fits'
# data_directory = "/home/mbouffard/Research/Github/HRS_data/WASP_178_b/NIRPS_genevaHE_2023apr02/data" + "/"

with fits.open(fits_file) as fitsObject:
    hdr = fitsObject[0].header
    print(repr(hdr))
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILENAME= '2697102o'           / filename anticipated by fitspipe server
# PATHNAME= '/data/sessions/spirou/21BQ20-Jan15' / Original directory name at acqu
# DATE    = '2022-01-16T06:36:16' / UTC Date of file creation
# HSTTIME = 'Sat Jan 15 20:36:16 HST 2022' / Local time in Hawaii
# IMAGESWV= 'DetCom-SPIRou v1.20 svn 13907 (compiled Aug 25 2020)' / Image creatio
# IMAGELBV= 'CFHT libdetcom v1.10 svn 13902 (compiled Aug 25 2020)' / Image creati
# RAMPSWV = 'fitspipe v2.12 (Jul 26 2018)' / RAMP fitting software version
# OBSTYPE = 'OBJECT  '           / Observation / Exposure type
# EXPTYPE = 'OBJECT  '           / See OBSTYPE
# EXPREQ  =               61.291 / [sec] Requested integration time
# EXPTIME =               61.291 / [sec] Integration time
# ...
